# %% [markdown]
# Need to install GeoPandas at the anaconda prompt: "conda install -c conda-forge geopandas"

# %%
import geopandas
import matplotlib.pyplot as plt
import os

# %%
fn1=r"C:\Users\rniswon\Documents\Data\Workshops\Advanced_SW-GW_2018\Test_problems\Exercise_2\examples\sagehen\hru_params\hru_params.shp"
os.path.isfile(fn1)
# Out:
# True

# %%
hru=geopandas.read_file(fn1)

# %%
#hru.columns

# %%
p2=hru.plot(column="DEM_ADJ")

# %%
fn2=r"C:\Users\rniswon\Documents\Data\Workshops\Advanced_SW-GW_2018\Test_problems\Exercise_2\examples\sagehen\shapefiles\watershed.shp"
boundary=geopandas.read_file(fn2)

# %%
boundary.plot(ax=hru.plot(column="DEM_ADJ"), color='none', edgecolor='black')
#boundary.plot(color='none', edgecolor='black')
