# %% [markdown]
# ## Accelerate Sensitivity Analysis & Model Calibration Using pyGSFLOW

# %% [markdown]
# <img src = "./figures/WorkFlow.PNG">

# %% [markdown]
# ### Agenda
# * Plot PRMS 2D data
# * Change 2D data by a scalar factor
# * Change zones in 2D maps using conditional masks
# * Simple sensitivity analysis
# * Comparing simulations and measurements
# * Calibration

# %%
import os
from gsflow import Gsflow
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
## The GSFLOW model is loaded as follows
control_file = r"../models_data/gsflow/saghen_new_cont.control"
gs = Gsflow(control_file=control_file)
# Out:
# PyGSFLOW ------ V0.0
# Control file is loaded
# Working on loading PRMS model ...
# Parameters will be read from a file/ files...
# Work on loadind the parameter files .....
# Prms model is loaded .....
# Working on loading MODFLOW files ....
#    loading iuzfbnd array...
#    loading irunbnd array...
#    loading vks array...
#    loading eps array...
#    loading thts array...
# stress period 1:
#    loading finf array...
# stress period 2:
# MOSFLOW files are loaded ...

# %%
#gs.prms.Data.data_df.to_csv("temp.csv")
gs.prms.parameters.get_record_names()
# Out:
# ['ncascade',
#  'ncascdgw',
#  'ndays',
#  'ndepl',
#  'ndeplval',
#  'nevap',
#  'ngw',
#  'ngwcell',
#  'nhru',
#  'nhrucell',
#  'nlake',
#  'nlake_hrus',
#  'nmonths',
#  'nobs',
#  'nrain',
#  'nreach',
#  'nsegment',
#  'nsnow',
#  'nsol',
#  'nssr',
#  'nsub',
#  'ntemp',
#  'one',
#  'adjmix_rain',
#  'basin_tsta',
#  'carea_max',
#  'dday_intcp',
#  'dday_slope',
#  'fastcoef_lin',
#  'fastcoef_sq',
#  'gwflow_coef',
#  'hru_percent_imperv',
#  'hru_subbasin',
#  'hru_tlaps',
#  'hru_tsta',
#  'jh_coef',
#  'pref_flow_den',
#  'rain_adj',
#  'sat_threshold',
#  'slowcoef_lin',
#  'slowcoef_sq',
#  'smidx_coef',
#  'snow_adj',
#  'soil_moist_max',
#  'soil_rechr_max',
#  'ssr2gw_rate',
#  'subbasin_down',
#  'tmax_allrain',
#  'tmax_allsnow',
#  'tmax_lapse',
#  'tmin_lapse',
#  'tsta_elev',
#  'cascade_flg',
#  'cascade_tol',
#  'circle_switch',
#  'gvr_cell_id',
#  'gw_down_id',
#  'gw_pct_up',
#  'gw_strmseg_down_id',
#  'gw_up_id',
#  'hru_down_id',
#  'hru_pct_up',
#  'hru_strmseg_down_id',
#  'hru_up_id',
#  'albset_rna',
#  'albset_rnm',
#  'albset_sna',
#  'albset_snm',
#  'cecn_coef',
#  'den_init',
#  'den_max',
#  'elev_units',
#  'emis_noppt',
#  'epan_coef',
#  'freeh2o_cap',
#  'gwsink_coef',
#  'gwstor_init',
#  'gwstor_min',
#  'hru_deplcrv',
#  'imperv_stor_max',
#  'mapvars_freq',
#  'mapvars_units',
#  'max_missing',
#  'melt_force',
#  'melt_look',
#  'outlet_sta',
#  'potet_sublim',
#  'ppt_rad_adj',
#  'precip_units',
#  'print_freq',
#  'print_type',
#  'prms_warmup',
#  'radadj_intcp',
#  'radadj_slope',
#  'radj_sppt',
#  'radj_wppt',
#  'radmax',
#  'runoff_units',
#  'settle_const',
#  'smidx_exp',
#  'snarea_curve',
#  'snarea_thresh',
#  'snowinfil_max',
#  'soil2gw_max',
#  'ssr2gw_exp',
#  'ssstor_init',
#  'temp_units',
#  'transp_beg',
#  'transp_end',
#  'transp_tmax',
#  'tstorm_mo',
#  'cov_type',
#  'covden_sum',
#  'covden_win',
#  'hru_area',
#  'hru_aspect',
#  'hru_elev',
#  'hru_lat',
#  'hru_psta',
#  'hru_slope',
#  'hru_type',
#  'jh_coef_hru',
#  'lake_hru_id',
#  'rad_trncf',
#  'snow_intcp',
#  'soil_moist_init',
#  'soil_rechr_init',
#  'soil_type',
#  'srain_intcp',
#  'tmax_adj',
#  'tmax_index',
#  'tmin_adj',
#  'wrain_intcp']

# %% [markdown]
# ### (1) Visualize PRMS data

# %%
print(gs.prms.parameters.get_record("ssr2gw_rate"))
# Out:
# ####
# ssr2gw_rate 10
# 1
# nssr
# 6468
# 2
# 0.0
# 0.0
# 0.0
# 0.0.
# .
# .
# ####

# %%
Params = gs.prms.parameters
gs.prms.parameters.get_values("ssr2gw_rate")
# Out:
# array([ 0.,  0.,  0., ...,  0.,  0.,  0.])

# %%
nrow = 77
ncol = 84
ssr2gw_rate = Params.get_values("ssr2gw_rate").reshape(nrow, ncol)
plt.imshow(ssr2gw_rate); plt.colorbar()

# %%
# 2D data
param = gs.prms.parameters.get_record('rain_adj')
print(param)
# Out:
# ####
# rain_adj 10
# 2
# nhru
# nmonths
# 77616
# 2
# 1.223373
# 1.214444
# 1.205549
# 1.196689.
# .
# .
# ####

# %%
rainadj = gs.prms.parameters.get_values('rain_adj')
rainadj = rainadj.reshape(12,nrow,ncol)
fig = plt.figure(figsize=(15,5)); 
for mon in range(12): 
    txt = "Mon {}".format(mon+1)
    ax = plt.subplot(2,6,mon+1) 
    ax.set_title(txt)
    img = ax.imshow(rainadj[mon,:,:], cmap='jet')
    
    fig.colorbar(img, ax= ax)
    ax.set_aspect('auto')
plt.tight_layout(h_pad=1)

# %% [markdown]
# ### (2) Scale parameter by a scalar value

# %%
# If you cannot remmber the parameter name,  you may list the parameter names
#gs.prms.parameters.get_record_names()

# %%
# In this exercise, let us change the model mode to "PRMS" becuase it's quick to run it. The same exercise
# can be made using GSFLOW model; however, runing the model will take a longer period of time
gs.control.set_values("model_mode", ['PRMS'])

# %%
gs.write_input(workspace=r"./prms_files")
# Out:
# Writing the project files .....
#
# changing model workspace...
#    D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files
# Control file is written...
# Parameters files are written...
# Data file is written...
# Modflow files are written...

# %%
gs.gsflow_exe = os.path.abspath(r"../../bin/gsflow.exe")
gs.run_model()
# Out:
# pyGSFLOW is using the following executable to run the model: D:\Training\gsflowID2447_classrepo\bin\gsflow.exe
#
# (base) D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files>D:\Training\gsflowID2447_classrepo\bin\gsflow.exe D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_cont.control
#
#                Precipitation-Runoff Modeling System (PRMS)
#                        Version 5.0.0 06/01/2018
#
#         Process            Available Modules
# --------------------------------------------------------------------
#   Basin Definition: basin
#     Cascading Flow: cascade
#   Time Series Data: obs, water_use_read, dynamic_param_read
#    Potet Solar Rad: soltab
#   Temperature Dist: temp_1sta, temp_laps, temp_dist2, climate_hru
#        Precip Dist: precip_1sta, precip_laps, precip_dist2,
#                     climate_hru
# Temp & Precip Dist: xyz_dist, ide_dist
#     Solar Rad Dist: ccsolrad, ddsolrad, climate_hru
# Transpiration Dist: transp_tindex, climate_hru, transp_frost
#       Potential ET: potet_hamon, potet_jh, potet_pan, climate_hru,
#                     potet_hs, potet_pt, potet_pm, potet_pm_sta
#       Interception: intcp
#      Snow Dynamics: snowcomp
#     Surface Runoff: srunoff_smidx, srunoff_carea
#          Soil Zone: soilzone
#        Groundwater: gwflow
# Streamflow Routing: strmflow, strmflow_in_out, muskingum,
#                     muskingum_lake
# Stream Temperature: stream_temp
#     Output Summary: basin_sum, subbasin, map_results, prms_summary,
#                     nhru_summary, nsub_summary, water_balance
#                     basin_summary, nsegment_summary
#      Preprocessing: write_climate_hru, frost_date
# --------------------------------------------------------------------
#
#
# ==========================================================================
# Please give careful consideration to fixing all ERROR and WARNING messages
# ==========================================================================
#
#
#     Active modules listed in the order in which they are called
#
#         Process                   Module                Version Date
# ====================================================================
# GSFLOW Computation Order       gsflow_prms                2018-09-26
# Basin Definition               basin                      2018-04-06
# Cascading Flow                 cascade                    2018-05-25
# Common States and Fluxes       climateflow                2018-09-19
# Potential Solar Radiation      soltab                     2016-09-09
# PRMS Set Time Variables        prms_time                  2015-03-31
# Time Series Data               obs                        2018-02-23
# Temperature Distribution       temp_1sta                  2018-01-16
# Precipitation Distribution     precip_1sta                2016-10-21
# Solar Radiation Distribution   ddsolrad                   2016-11-03
# Transpiration Distribution     transp_tindex              2015-01-06
# Potential Evapotranspiration   potet_jh                   2016-05-10
# Canopy Interception            intcp                      2018-02-26
# Snow Dynamics                  snowcomp                   2018-05-04
# Surface Runoff                 srunoff_smidx              2018-04-25
# Soil Zone Computations         soilzone                   2018-09-19
# Groundwater                    gwflow                     2018-02-26
# Streamflow Routing             strmflow                   2014-12-02
# Summary                        basin_sum                  2017-10-21
# Output Summary                 map_results                2018-04-25
#  WARNING, map_results requested with nmapOutVars equal 0
#  no map_results output is produced
# Output Summary                 subbasin                   2018-04-25
# ====================================================================
#
# Writing PRMS Water Budget File: D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_model_output.out
#
# Simulation time period: 1982/08/01 - 1997/03/31
#
# ====================================================================
#
#
#
# WARNING: parameter_check_flag is duplicated in the control file D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_cont.control.
#
#
#
# WARNING: print_debug is duplicated in the control file D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_cont.control.
#
#
# WARNING: dimension 'nlake_hrus' is not required; file is D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_par_0.params; line number 38
#
# WARNING: parameter 'hru_tlaps' is not required; file is D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_par_0.params; line number 19579
#
# WARNING: parameter 'gvr_cell_id' is not required; file is D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_par_1.params; line number 24
#
# WARNING: parameter 'mapvars_freq' is not required; file is D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_par_2.params; line number 137
#
# WARNING: parameter 'mapvars_units' is not required; file is D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_par_2.params; line number 144
#
# WARNING: parameter 'prms_warmup' is not required; file is D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_par_2.params; line number 225
#
# WARNING: parameter 'lake_hru_id' is not required; file is D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_par_3.params; line number 71217
#
# WARNING: parameter snowpack_init is used by module snowcomp but values are not
#          set in the Parameter File. Module default values are being used.

# %%
gs.prms.get_statVar()
# Out:
# Loading the statvar output file .....
# Finished Load the statvar output file .....
#         ID  Year  Month  Day  Hour  Minute  Second  basin_cfs_1  \
# 0        1  1982      8    1     0       0       0     1.652899
# 1        2  1982      8    2     0       0       0     1.622443
# 2        3  1982      8    3     0       0       0     1.595032
# 3        4  1982      8    4     0       0       0     1.568145
# 4        5  1982      8    5     0       0       0     1.541771
# 5        6  1982      8    6     0       0       0     1.515899
# 6        7  1982      8    7     0       0       0     1.490518
# 7        8  1982      8    8     0       0       0     1.628067
# 5353         0.881564       0.044026     510.869867          0.048329
# 5354         0.871146       0.032522     518.188000          0.049404
# 5355         0.962941       0.030818     525.355649          0.050116
# 5356         1.000000       0.000904     181.877041          0.049113
#
#            Date
# 0    1982-08-01
# 1    1982-08-02
# 2    1982-08-03
# 3    1982-08-04
# 4    1982-08-05
# 5    1982-08-06
# 6    1982-08-07
# 7    1982-08-08
# 8    1982-08-09
# 9    1982-08-10
# 10   1982-08-11
# 11   1982-08-12
# 12   1982-08-13
# 13   1982-08-14
# 14   1982-08-15
# 15   1982-08-16
# 16   1982-08-17
# 17   1982-08-18
# 18   1982-08-19
# 19   1982-08-20
# 20   1982-08-21
# 21   1982-08-22
# 22   1982-08-23
# 23   1982-08-24
# 24   1982-08-25
# 25   1982-08-26
# 26   1982-08-27
# 27   1982-08-28
# 28   1982-08-29
# 29   1982-08-30
# ...         ...
# 5327 1997-03-02
# 5328 1997-03-03
# 5329 1997-03-04
# 5330 1997-03-05
# 5331 1997-03-06
# 5332 1997-03-07
# 5333 1997-03-08
# 5334 1997-03-09
# 5335 1997-03-10
# 5336 1997-03-11
# 5337 1997-03-12
# 5338 1997-03-13
# 5339 1997-03-14
# 5340 1997-03-15
# 5341 1997-03-16
# 5342 1997-03-17
# 5343 1997-03-18
# 5344 1997-03-19
# 5345 1997-03-20
# 5346 1997-03-21
# 5347 1997-03-22
# 5348 1997-03-23
# 5349 1997-03-24
# 5350 1997-03-25
# 5351 1997-03-26
# 5352 1997-03-27
# 5353 1997-03-28
# 5354 1997-03-29
# 5355 1997-03-30
# 5356 1997-03-31
#
# [5357 rows x 20 columns]

# %%
basic_cfs_before = gs.prms.stat.stat_df['basin_cfs_1'].values

# %%
## save a copy of rain_adj before we change ir
rain_adj_backup = np.copy(gs.prms.parameters.get_values('rain_adj'))
snow_adj_backup = np.copy(gs.prms.parameters.get_values('snow_adj'))

# %%
## Let us just remove the effect of rain by assiging rain adj factor to 0.0
newrainadj = rain_adj_backup * 0.0
gs.prms.parameters.set_values('rain_adj', newrainadj)
gs.prms.parameters.set_values('snow_adj', 0.0*snow_adj_backup)

# Write input files
gs.write_input(workspace=r"./prms_files")

# run
gs.run_model()

# Get results
gs.prms.get_statVar() 
basic_cfs_after = gs.prms.stat.stat_df['basin_cfs_1'].values
# Out:
# Writing the project files .....
#
# changing model workspace...
#    D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files
# Control file is written...
# Parameters files are written...
# Data file is written...
# Modflow files are written...
# pyGSFLOW is using the following executable to run the model: D:\Training\gsflowID2447_classrepo\bin\gsflow.exe
#
# (base) D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files>D:\Training\gsflowID2447_classrepo\bin\gsflow.exe D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_cont.control
#
#                Precipitation-Runoff Modeling System (PRMS)
#                        Version 5.0.0 06/01/2018
#
#         Process            Available Modules
# --------------------------------------------------------------------
#   Basin Definition: basin
#     Cascading Flow: cascade
#   Time Series Data: obs, water_use_read, dynamic_param_read
#    Potet Solar Rad: soltab
#   Temperature Dist: temp_1sta, temp_laps, temp_dist2, climate_hru
#        Precip Dist: precip_1sta, precip_laps, precip_dist2,
#                     climate_hru
# Temp & Precip Dist: xyz_dist, ide_dist
#     Solar Rad Dist: ccsolrad, ddsolrad, climate_hru
# Transpiration Dist: transp_tindex, climate_hru, transp_frost
#       Potential ET: potet_hamon, potet_jh, potet_pan, climate_hru,
#                     potet_hs, potet_pt, potet_pm, potet_pm_sta
#       Interception: intcp
#      Snow Dynamics: snowcomp
#     Surface Runoff: srunoff_smidx, srunoff_carea
#          Soil Zone: soilzone
#        Groundwater: gwflow
# Streamflow Routing: strmflow, strmflow_in_out, muskingum,
#                     muskingum_lake
# Stream Temperature: stream_temp
#     Output Summary: basin_sum, subbasin, map_results, prms_summary,
#                     nhru_summary, nsub_summary, water_balance
#                     basin_summary, nsegment_summary
#      Preprocessing: write_climate_hru, frost_date
# --------------------------------------------------------------------
#
#
# ==========================================================================
# Please give careful consideration to fixing all ERROR and WARNING messages
# ==========================================================================
#
#
#     Active modules listed in the order in which they are called
#
#         Process                   Module                Version Date
# ====================================================================
# GSFLOW Computation Order       gsflow_prms                2018-09-26
# Basin Definition               basin                      2018-04-06
# Cascading Flow                 cascade                    2018-05-25
# Common States and Fluxes       climateflow                2018-09-19
# Potential Solar Radiation      soltab                     2016-09-09
# PRMS Set Time Variables        prms_time                  2015-03-31
# Time Series Data               obs                        2018-02-23
# Temperature Distribution       temp_1sta                  2018-01-16
# Precipitation Distribution     precip_1sta                2016-10-21
# Solar Radiation Distribution   ddsolrad                   2016-11-03
# Transpiration Distribution     transp_tindex              2015-01-06
# Potential Evapotranspiration   potet_jh                   2016-05-10
# Canopy Interception            intcp                      2018-02-26
# Snow Dynamics                  snowcomp                   2018-05-04
# Surface Runoff                 srunoff_smidx              2018-04-25
# Soil Zone Computations         soilzone                   2018-09-19
# Groundwater                    gwflow                     2018-02-26
# Streamflow Routing             strmflow                   2014-12-02
# Summary                        basin_sum                  2017-10-21
# Output Summary                 map_results                2018-04-25
#  WARNING, map_results requested with nmapOutVars equal 0
#  no map_results output is produced
# Output Summary                 subbasin                   2018-04-25
# ====================================================================
#
# Writing PRMS Water Budget File: D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_model_output.out
#
# Simulation time period: 1982/08/01 - 1997/03/31
#
# ====================================================================
#
#
#
# WARNING: parameter_check_flag is duplicated in the control file D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_cont.control.
#
#
#
# WARNING: print_debug is duplicated in the control file D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_cont.control.
#
#
# WARNING: dimension 'nlake_hrus' is not required; file is D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_par_0.params; line number 38
#
# WARNING: parameter 'hru_tlaps' is not required; file is D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_par_0.params; line number 19579
#
# WARNING: parameter 'gvr_cell_id' is not required; file is D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_par_1.params; line number 24
#
# WARNING: parameter 'mapvars_freq' is not required; file is D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_par_2.params; line number 137
#
# WARNING: parameter 'mapvars_units' is not required; file is D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_par_2.params; line number 144
#
# WARNING: parameter 'prms_warmup' is not required; file is D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_par_2.params; line number 225
#
# WARNING: parameter 'lake_hru_id' is not required; file is D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_par_3.params; line number 71217
#
# WARNING: parameter snowpack_init is used by module snowcomp but values are not
#          set in the Parameter File. Module default values are being used.
# Loading the statvar output file .....
# Finished Load the statvar output file .....

# %%
dates = gs.prms.stat.stat_df['Date'].values
plt.figure(figsize=(10,7))
plt.plot(dates, (basic_cfs_before), 'b', label = 'before' )
plt.plot(dates,(basic_cfs_after), 'r', label = 'after' )
plt.legend()

# %% [markdown]
# ### (2) Use "array masking" to change parameters

# %%
# masking
Params = gs.prms.parameters
hru_elev = np.copy(Params.get_values("hru_elev"))
hru_elev = hru_elev.reshape(nrow, ncol)
plt.imshow(hru_elev); plt.colorbar()

# %%
mask = hru_elev<7000
plt.imshow(mask); plt.colorbar()

# %%
rain_adj_jan = np.copy(rainadj[0,:,:])
rain_adj_jan[mask] = rain_adj_jan[mask] * 0.8
plt.imshow(rain_adj_jan); plt.colorbar()

# %%
## Can you change ssr2_gw_rate values in subbasin 10?

# %%
hru_subbasin = gs.mf.uzf.irunbnd.array
plt.imshow(hru_subbasin); plt.colorbar()

# %%
ssr2gw_rate = Params.get_values("ssr2gw_rate").reshape(nrow, ncol)
plt.imshow(ssr2gw_rate); plt.colorbar()

# %%
ssr2gw_rate[hru_subbasin==10] = ssr2gw_rate[hru_subbasin==10] * 0.0
plt.imshow(ssr2gw_rate); plt.colorbar()

# %%
# The mask can be complex 
mask2 = np.logical_and(hru_subbasin==10, hru_elev <7500)
plt.imshow(mask2)

# %% [markdown]
# ## (3) Sensitivity Analysis

# %%
# %%time
## Before Calibration, let us do sensitivity analysis.... simple one!
#parameters = ['gwflow_coef', 'gwsink_coef', 'ssr2gw_rate', 'slowcoef_lin', 'slowcoef_sq', 'smidx_coef', 
#              'snarea_curve', 'snarea_thresh']

parameters = ['snarea_curve', 'ssr2gw_rate',  'gwflow_coef']

control_file = r"../models_data/gsflow/saghen_new_cont.control"

# load model files
gs = Gsflow(control_file=control_file)
gs.gsflow_exe = os.path.abspath(r"../../bin/gsflow.exe")

# Let us use PRMS
gs.control.set_values("model_mode", ['PRMS'])
gs.control.set_values("print_debug", [-1]) # this will turn off screen printout and reduce output to the notebook
gs.control.set_values(name='end_time', values=[1990,1,1,0,0,0])

Params = gs.prms.parameters

# Save a copy of parameter values before they changes
orig_params = {}
for par in parameters:
    orig_params[par] = np.copy(Params.get_values(par))

orig_params
# Out:
# PyGSFLOW ------ V0.0
# Control file is loaded
# Working on loading PRMS model ...
# Parameters will be read from a file/ files...
# Work on loadind the parameter files .....
# Prms model is loaded .....
# Working on loading MODFLOW files ....
#    loading iuzfbnd array...
#    loading irunbnd array...
#    loading vks array...
#    loading eps array...
#    loading thts array...
# stress period 1:
#    loading finf array...
# stress period 2:
# MOSFLOW files are loaded ...
# Wall time: 2.25 s

# %% [markdown]
# ##### Automation of Sensitivity Analysis
# We are going to use two loops: loop over parameters and loop over scaling factor. Within the parameter loop, the values of the parameter will be changed by multipling it by a list of scaling factors.

# %%
# %%time
# Parameters to be explored....
#parameters = ['gwflow_coef', 'gwsink_coef', 'ssr2gw_rate', 'slowcoef_lin', 'slowcoef_sq', 'smidx_coef',
#              'snarea_curve', 'snarea_thresh']
parameters = ['snarea_curve', 'ssr2gw_rate',  'gwflow_coef']
factors = [0.5, 0.75, 1.0, 1.25, 1.5]
all_sens = {}

## Nested Loop
for par in parameters: # loop over parameters   
    responce = []
    for facc in factors: # loop over scaling factor       
        print("\n****** Par =  {}, Facc = {} ****** ".format(par, facc))
        
        Params.set_values(name=par, values = orig_params[par]*facc) # change the parameter  
        
        gs.write_input(workspace=r"./prms_files")                   # write input
        
        gs.run_model()                                              # run the model and wait for results
        
        gs.prms.get_statVar()                                       # load results from Statvar 
        
        mean_outflow = gs.prms.stat.stat_df['basin_cfs_1'].mean()   # compute the mean stream flow
        
        responce.append(mean_outflow)                               # save results
    
    all_sens[par] = responce
    Params.set_values(name=par, values = orig_params[par])
# Out:
# ****** Par =  snarea_curve, Facc = 0.5 ******
# Writing the project files .....
#
# changing model workspace...
#    D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files
# Control file is written...
# Parameters files are written...
# Data file is written...
# Modflow files are written...
# pyGSFLOW is using the following executable to run the model: D:\Training\gsflowID2447_classrepo\bin\gsflow.exe
#
# (base) D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files>D:\Training\gsflowID2447_classrepo\bin\gsflow.exe D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_cont.control
#
#                Precipitation-Runoff Modeling System (PRMS)
#                        Version 5.0.0 06/01/2018
#
#         Process            Available Modules
# --------------------------------------------------------------------
#   Basin Definition: basin
#     Cascading Flow: cascade
#   Time Series Data: obs, water_use_read, dynamic_param_read
#    Potet Solar Rad: soltab
#   Temperature Dist: temp_1sta, temp_laps, temp_dist2, climate_hru
#        Precip Dist: precip_1sta, precip_laps, precip_dist2,
#                     climate_hru
# Temp & Precip Dist: xyz_dist, ide_dist
#     Solar Rad Dist: ccsolrad, ddsolrad, climate_hru
# Transpiration Dist: transp_tindex, climate_hru, transp_frost
#       Potential ET: potet_hamon, potet_jh, potet_pan, climate_hru,
#                     potet_hs, potet_pt, potet_pm, potet_pm_sta
#       Interception: intcp
#      Snow Dynamics: snowcomp
#     Surface Runoff: srunoff_smidx, srunoff_carea
#          Soil Zone: soilzone
#        Groundwater: gwflow
# Streamflow Routing: strmflow, strmflow_in_out, muskingum,
#                     muskingum_lake
# Stream Temperature: stream_temp
#     Output Summary: basin_sum, subbasin, map_results, prms_summary,
#                     nhru_summary, nsub_summary, water_balance
#                     basin_summary, nsegment_summary
#      Preprocessing: write_climate_hru, frost_date
# --------------------------------------------------------------------
#
#
# ==========================================================================
# Please give careful consideration to fixing all ERROR and WARNING messages
# ==========================================================================
#
#
#     Active modules listed in the order in which they are called
#
#         Process                   Module                Version Date
# ====================================================================
# GSFLOW Computation Order       gsflow_prms                2018-09-26
# Basin Definition               basin                      2018-04-06
# Cascading Flow                 cascade                    2018-05-25
# Common States and Fluxes       climateflow                2018-09-19
# Potential Solar Radiation      soltab                     2016-09-09
# PRMS Set Time Variables        prms_time                  2015-03-31
# Time Series Data               obs                        2018-02-23
# Temperature Distribution       temp_1sta                  2018-01-16
# Precipitation Distribution     precip_1sta                2016-10-21
# Solar Radiation Distribution   ddsolrad                   2016-11-03
# Transpiration Distribution     transp_tindex              2015-01-06
# Potential Evapotranspiration   potet_jh                   2016-05-10
# Canopy Interception            intcp                      2018-02-26
# Snow Dynamics                  snowcomp                   2018-05-04
# Surface Runoff                 srunoff_smidx              2018-04-25
# Soil Zone Computations         soilzone                   2018-09-19
# Groundwater                    gwflow                     2018-02-26
# Streamflow Routing             strmflow                   2014-12-02
# Summary                        basin_sum                  2017-10-21
# Output Summary                 map_results                2018-04-25
#  WARNING, map_results requested with nmapOutVars equal 0
#  no map_results output is produced
# Output Summary                 subbasin                   2018-04-25
# ====================================================================
#
# Writing PRMS Water Budget File: D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_model_output.out
#
# Simulation time period: 1982/08/01 - 1990/01/01
#
# ====================================================================
#
#
#
# WARNING: parameter_check_flag is duplicated in the control file D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_cont.control.
#
#
#
# WARNING: print_debug is duplicated in the control file D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_cont.control.
#
#
# WARNING: dimension 'nlake_hrus' is not required; file is D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_par_0.params; line number 38
#
# WARNING: parameter 'hru_tlaps' is not required; file is D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_par_0.params; line number 19579
#
# WARNING: parameter 'gvr_cell_id' is not required; file is D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_par_1.params; line number 24
#
# WARNING: parameter 'mapvars_freq' is not required; file is D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_par_2.params; line number 137
#
# WARNING: parameter 'mapvars_units' is not required; file is D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_par_2.params; line number 144
#
# WARNING: parameter 'prms_warmup' is not required; file is D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_par_2.params; line number 225
#
# WARNING: parameter 'lake_hru_id' is not required; file is D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_par_3.params; line number 71217
#
# WARNING: parameter snowpack_init is used by module snowcomp but values are not
#          set in the Parameter File. Module default values are being used.
# Loading the statvar output file .....
# Finished Load the statvar output file .....
#
# ****** Par =  snarea_curve, Facc = 0.75 ******
# Writing the project files .....
#
# changing model workspace...
#    D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files
# Control file is written...
# Parameters files are written...
# Data file is written...
# Modflow files are written...
# pyGSFLOW is using the following executable to run the model: D:\Training\gsflowID2447_classrepo\bin\gsflow.exe
#
# (base) D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files>D:\Training\gsflowID2447_classrepo\bin\gsflow.exe D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_cont.control
#
#                Precipitation-Runoff Modeling System (PRMS)
#                        Version 5.0.0 06/01/2018
#
#         Process            Available Modules
# --------------------------------------------------------------------
#   Basin Definition: basin
#     Cascading Flow: cascade
#   Time Series Data: obs, water_use_read, dynamic_param_read
#    Potet Solar Rad: soltab
#   Temperature Dist: temp_1sta, temp_laps, temp_dist2, climate_hru
#        Precip Dist: precip_1sta, precip_laps, precip_dist2,
#                     climate_hru
# Temp & Precip Dist: xyz_dist, ide_dist
#     Solar Rad Dist: ccsolrad, ddsolrad, climate_hru
# Transpiration Dist: transp_tindex, climate_hru, transp_frost
#       Potential ET: potet_hamon, potet_jh, potet_pan, climate_hru,
#                     potet_hs, potet_pt, potet_pm, potet_pm_sta
#       Interception: intcp
#      Snow Dynamics: snowcomp
#     Surface Runoff: srunoff_smidx, srunoff_carea
#          Soil Zone: soilzone
#        Groundwater: gwflow
# Streamflow Routing: strmflow, strmflow_in_out, muskingum,
#                     muskingum_lake
# Stream Temperature: stream_temp
#     Output Summary: basin_sum, subbasin, map_results, prms_summary,
#                     nhru_summary, nsub_summary, water_balance
#                     basin_summary, nsegment_summary
#      Preprocessing: write_climate_hru, frost_date
# --------------------------------------------------------------------
#
#
# ==========================================================================
# Please give careful consideration to fixing all ERROR and WARNING messages
# ==========================================================================
#
#
#     Active modules listed in the order in which they are called
#
#         Process                   Module                Version Date
# ====================================================================
# GSFLOW Computation Order       gsflow_prms                2018-09-26
# Basin Definition               basin                      2018-04-06
# Cascading Flow                 cascade                    2018-05-25
# Common States and Fluxes       climateflow                2018-09-19
# Potential Solar Radiation      soltab                     2016-09-09
# PRMS Set Time Variables        prms_time                  2015-03-31
# Time Series Data               obs                        2018-02-23
# Temperature Distribution       temp_1sta                  2018-01-16
# Precipitation Distribution     precip_1sta                2016-10-21
# Solar Radiation Distribution   ddsolrad                   2016-11-03
# Transpiration Distribution     transp_tindex              2015-01-06
# Potential Evapotranspiration   potet_jh                   2016-05-10
# Canopy Interception            intcp                      2018-02-26
# Snow Dynamics                  snowcomp                   2018-05-04
# Surface Runoff                 srunoff_smidx              2018-04-25
# Soil Zone Computations         soilzone                   2018-09-19
# Groundwater                    gwflow                     2018-02-26
# Streamflow Routing             strmflow                   2014-12-02
# Summary                        basin_sum                  2017-10-21
# Output Summary                 map_results                2018-04-25
#  WARNING, map_results requested with nmapOutVars equal 0
#  no map_results output is produced
# Output Summary                 subbasin                   2018-04-25
# ====================================================================
# Writing PRMS Water Budget File: D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_model_output.out
#
# Simulation time period: 1982/08/01 - 1990/01/01
#
# ====================================================================
#
#
#
# WARNING: parameter_check_flag is duplicated in the control file D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_cont.control.
#
#
#
# WARNING: print_debug is duplicated in the control file D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_cont.control.
#
#
# WARNING: dimension 'nlake_hrus' is not required; file is D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_par_0.params; line number 38
#
# WARNING: parameter 'hru_tlaps' is not required; file is D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_par_0.params; line number 19579
#
# WARNING: parameter 'gvr_cell_id' is not required; file is D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_par_1.params; line number 24
#
# WARNING: parameter 'mapvars_freq' is not required; file is D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_par_2.params; line number 137
#
# WARNING: parameter 'mapvars_units' is not required; file is D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_par_2.params; line number 144
#
# WARNING: parameter 'prms_warmup' is not required; file is D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_par_2.params; line number 225
#
# WARNING: parameter 'lake_hru_id' is not required; file is D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_par_3.params; line number 71217
#
# WARNING: parameter snowpack_init is used by module snowcomp but values are not
#          set in the Parameter File. Module default values are being used.
# Loading the statvar output file .....
# Finished Load the statvar output file .....
#
# ****** Par =  snarea_curve, Facc = 1.0 ******
# Writing the project files .....
#
# changing model workspace...
#    D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files
# Control file is written...
# Parameters files are written...
# Data file is written...
# Modflow files are written...
# pyGSFLOW is using the following executable to run the model: D:\Training\gsflowID2447_classrepo\bin\gsflow.exe
#
# (base) D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files>D:\Training\gsflowID2447_classrepo\bin\gsflow.exe D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_cont.control
#
#                Precipitation-Runoff Modeling System (PRMS)
#                        Version 5.0.0 06/01/2018
#
#         Process            Available Modules
# --------------------------------------------------------------------
#   Basin Definition: basin
#     Cascading Flow: cascade
#   Time Series Data: obs, water_use_read, dynamic_param_read
#    Potet Solar Rad: soltab
#   Temperature Dist: temp_1sta, temp_laps, temp_dist2, climate_hru
#        Precip Dist: precip_1sta, precip_laps, precip_dist2,
#                     climate_hru
# Temp & Precip Dist: xyz_dist, ide_dist
#     Solar Rad Dist: ccsolrad, ddsolrad, climate_hru
# Transpiration Dist: transp_tindex, climate_hru, transp_frost
#       Potential ET: potet_hamon, potet_jh, potet_pan, climate_hru,
#                     potet_hs, potet_pt, potet_pm, potet_pm_sta
#       Interception: intcp
#      Snow Dynamics: snowcomp
#     Surface Runoff: srunoff_smidx, srunoff_carea
#          Soil Zone: soilzone
#        Groundwater: gwflow
# Streamflow Routing: strmflow, strmflow_in_out, muskingum,
#                     muskingum_lake
# Stream Temperature: stream_temp
#     Output Summary: basin_sum, subbasin, map_results, prms_summary,
#                     nhru_summary, nsub_summary, water_balance
#                     basin_summary, nsegment_summary
#      Preprocessing: write_climate_hru, frost_date
# --------------------------------------------------------------------
#
#
# ==========================================================================
# Please give careful consideration to fixing all ERROR and WARNING messages
# ==========================================================================
#
#
#     Active modules listed in the order in which they are called
#
#         Process                   Module                Version Date
# ====================================================================
# GSFLOW Computation Order       gsflow_prms                2018-09-26
# Basin Definition               basin                      2018-04-06
# Cascading Flow                 cascade                    2018-05-25
# Common States and Fluxes       climateflow                2018-09-19
# Potential Solar Radiation      soltab                     2016-09-09
# PRMS Set Time Variables        prms_time                  2015-03-31
# Time Series Data               obs                        2018-02-23
# Temperature Distribution       temp_1sta                  2018-01-16
# Precipitation Distribution     precip_1sta                2016-10-21
# Solar Radiation Distribution   ddsolrad                   2016-11-03
# Transpiration Distribution     transp_tindex              2015-01-06
# Potential Evapotranspiration   potet_jh                   2016-05-10
# Canopy Interception            intcp                      2018-02-26
# Snow Dynamics                  snowcomp                   2018-05-04
# Surface Runoff                 srunoff_smidx              2018-04-25
# Soil Zone Computations         soilzone                   2018-09-19
# Groundwater                    gwflow                     2018-02-26
# Streamflow Routing             strmflow                   2014-12-02
# Summary                        basin_sum                  2017-10-21
# Output Summary                 map_results                2018-04-25
#  WARNING, map_results requested with nmapOutVars equal 0
#  no map_results output is produced
# Output Summary                 subbasin                   2018-04-25
# ====================================================================
#
# Writing PRMS Water Budget File: D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_model_output.out
#
# Simulation time period: 1982/08/01 - 1990/01/01
#
# ====================================================================
#
#
#
# WARNING: parameter_check_flag is duplicated in the control file D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_cont.control.
#
#
#
# WARNING: print_debug is duplicated in the control file D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_cont.control.
#
#
# WARNING: dimension 'nlake_hrus' is not required; file is D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_par_0.params; line number 38
#
# WARNING: parameter 'hru_tlaps' is not required; file is D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_par_0.params; line number 19579
#
# WARNING: parameter 'gvr_cell_id' is not required; file is D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_par_1.params; line number 24
#
# WARNING: parameter 'mapvars_freq' is not required; file is D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_par_2.params; line number 137
#
# WARNING: parameter 'mapvars_units' is not required; file is D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_par_2.params; line number 144
#
# WARNING: parameter 'prms_warmup' is not required; file is D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_par_2.params; line number 225
#
# WARNING: parameter 'lake_hru_id' is not required; file is D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_par_3.params; line number 71217
#
# WARNING: parameter snowpack_init is used by module snowcomp but values are not
#          set in the Parameter File. Module default values are being used.
# Loading the statvar output file .....
# Finished Load the statvar output file .....
#
# ****** Par =  snarea_curve, Facc = 1.25 ******
# Writing the project files .....
#
# changing model workspace...
#    D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files
# Control file is written...
# Parameters files are written...
# Data file is written...
# Modflow files are written...
# pyGSFLOW is using the following executable to run the model: D:\Training\gsflowID2447_classrepo\bin\gsflow.exe
#
# (base) D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files>D:\Training\gsflowID2447_classrepo\bin\gsflow.exe D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_cont.control
#
#                Precipitation-Runoff Modeling System (PRMS)
#                        Version 5.0.0 06/01/2018
#
#         Process            Available Modules
# --------------------------------------------------------------------
#   Basin Definition: basin
#     Cascading Flow: cascade
#   Time Series Data: obs, water_use_read, dynamic_param_read
#    Potet Solar Rad: soltab
#   Temperature Dist: temp_1sta, temp_laps, temp_dist2, climate_hru
#        Precip Dist: precip_1sta, precip_laps, precip_dist2,
#                     climate_hru
# Temp & Precip Dist: xyz_dist, ide_dist
#     Solar Rad Dist: ccsolrad, ddsolrad, climate_hru
# Transpiration Dist: transp_tindex, climate_hru, transp_frost
#       Potential ET: potet_hamon, potet_jh, potet_pan, climate_hru,
#                     potet_hs, potet_pt, potet_pm, potet_pm_sta
#       Interception: intcp
#      Snow Dynamics: snowcomp
#     Surface Runoff: srunoff_smidx, srunoff_carea
#          Soil Zone: soilzone
#        Groundwater: gwflow
# Streamflow Routing: strmflow, strmflow_in_out, muskingum,
#                     muskingum_lake
# Stream Temperature: stream_temp
#     Output Summary: basin_sum, subbasin, map_results, prms_summary,
#                     nhru_summary, nsub_summary, water_balance
#                     basin_summary, nsegment_summary
#      Preprocessing: write_climate_hru, frost_date
# --------------------------------------------------------------------
#
#
# ==========================================================================
# Please give careful consideration to fixing all ERROR and WARNING messages
# ==========================================================================
#
#
#     Active modules listed in the order in which they are called
#
#         Process                   Module                Version Date
# ====================================================================
# GSFLOW Computation Order       gsflow_prms                2018-09-26
# Basin Definition               basin                      2018-04-06
# Cascading Flow                 cascade                    2018-05-25
# Common States and Fluxes       climateflow                2018-09-19
# Potential Solar Radiation      soltab                     2016-09-09
# PRMS Set Time Variables        prms_time                  2015-03-31
# Time Series Data               obs                        2018-02-23
# Temperature Distribution       temp_1sta                  2018-01-16
# Precipitation Distribution     precip_1sta                2016-10-21
# Solar Radiation Distribution   ddsolrad                   2016-11-03
# Transpiration Distribution     transp_tindex              2015-01-06
# Potential Evapotranspiration   potet_jh                   2016-05-10
# Canopy Interception            intcp                      2018-02-26
# Snow Dynamics                  snowcomp                   2018-05-04
# Surface Runoff                 srunoff_smidx              2018-04-25
# Soil Zone Computations         soilzone                   2018-09-19
# Groundwater                    gwflow                     2018-02-26
# Streamflow Routing             strmflow                   2014-12-02
# Summary                        basin_sum                  2017-10-21
# Output Summary                 map_results                2018-04-25
#  WARNING, map_results requested with nmapOutVars equal 0
#  no map_results output is produced
# Output Summary                 subbasin                   2018-04-25
# ====================================================================
#
# Writing PRMS Water Budget File: D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_model_output.out
#
# Simulation time period: 1982/08/01 - 1990/01/01
#
# ====================================================================
#
#
#
# WARNING: parameter_check_flag is duplicated in the control file D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_cont.control.
#
#
#
# WARNING: print_debug is duplicated in the control file D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_cont.control.
#
#
# WARNING: dimension 'nlake_hrus' is not required; file is D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_par_0.params; line number 38
#
# WARNING: parameter 'hru_tlaps' is not required; file is D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_par_0.params; line number 19579
#
# WARNING: parameter 'gvr_cell_id' is not required; file is D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_par_1.params; line number 24
#
# WARNING: parameter 'mapvars_freq' is not required; file is D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_par_2.params; line number 137
#
# WARNING: parameter 'mapvars_units' is not required; file is D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_par_2.params; line number 144
#
# WARNING: parameter 'prms_warmup' is not required; file is D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_par_2.params; line number 225
#
# WARNING: parameter 'lake_hru_id' is not required; file is D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_par_3.params; line number 71217
#
# WARNING: parameter snowpack_init is used by module snowcomp but values are not
#          set in the Parameter File. Module default values are being used.
# Loading the statvar output file .....
# Finished Load the statvar output file .....
#
# ****** Par =  snarea_curve, Facc = 1.5 ******
# Writing the project files .....
#
# changing model workspace...
#    D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files
# Control file is written...
# Parameters files are written...
# Data file is written...
# Modflow files are written...
# pyGSFLOW is using the following executable to run the model: D:\Training\gsflowID2447_classrepo\bin\gsflow.exe
#
# (base) D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files>D:\Training\gsflowID2447_classrepo\bin\gsflow.exe D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_cont.control
#
#                Precipitation-Runoff Modeling System (PRMS)
#                        Version 5.0.0 06/01/2018
#
#         Process            Available Modules
# --------------------------------------------------------------------
#   Basin Definition: basin
#     Cascading Flow: cascade
#   Time Series Data: obs, water_use_read, dynamic_param_read
#    Potet Solar Rad: soltab
#   Temperature Dist: temp_1sta, temp_laps, temp_dist2, climate_hru
#        Precip Dist: precip_1sta, precip_laps, precip_dist2,
#                     climate_hru
# Temp & Precip Dist: xyz_dist, ide_dist
#     Solar Rad Dist: ccsolrad, ddsolrad, climate_hru
# Transpiration Dist: transp_tindex, climate_hru, transp_frost
#       Potential ET: potet_hamon, potet_jh, potet_pan, climate_hru,
#                     potet_hs, potet_pt, potet_pm, potet_pm_sta
#       Interception: intcp
#      Snow Dynamics: snowcomp
#     Surface Runoff: srunoff_smidx, srunoff_carea
#          Soil Zone: soilzone
#        Groundwater: gwflow
# Streamflow Routing: strmflow, strmflow_in_out, muskingum,
#                     muskingum_lake
# Stream Temperature: stream_temp
#     Output Summary: basin_sum, subbasin, map_results, prms_summary,
#                     nhru_summary, nsub_summary, water_balance
#                     basin_summary, nsegment_summary
#      Preprocessing: write_climate_hru, frost_date
# --------------------------------------------------------------------
#
#
# ==========================================================================
# Please give careful consideration to fixing all ERROR and WARNING messages
# ==========================================================================
#
#
#     Active modules listed in the order in which they are called
#
#         Process                   Module                Version Date
# ====================================================================
# GSFLOW Computation Order       gsflow_prms                2018-09-26
# Basin Definition               basin                      2018-04-06
# Cascading Flow                 cascade                    2018-05-25
# Common States and Fluxes       climateflow                2018-09-19
# Potential Solar Radiation      soltab                     2016-09-09
# PRMS Set Time Variables        prms_time                  2015-03-31
# Time Series Data               obs                        2018-02-23
# Temperature Distribution       temp_1sta                  2018-01-16
# Precipitation Distribution     precip_1sta                2016-10-21
# Solar Radiation Distribution   ddsolrad                   2016-11-03
# Transpiration Distribution     transp_tindex              2015-01-06
# Potential Evapotranspiration   potet_jh                   2016-05-10
# Canopy Interception            intcp                      2018-02-26
# Snow Dynamics                  snowcomp                   2018-05-04
# Surface Runoff                 srunoff_smidx              2018-04-25
# Soil Zone Computations         soilzone                   2018-09-19
# Groundwater                    gwflow                     2018-02-26
# Streamflow Routing             strmflow                   2014-12-02
# Summary                        basin_sum                  2017-10-21
# Output Summary                 map_results                2018-04-25
#  WARNING, map_results requested with nmapOutVars equal 0
#  no map_results output is produced
# Output Summary                 subbasin                   2018-04-25
# ====================================================================
# Writing PRMS Water Budget File: D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_model_output.out
#
# Simulation time period: 1982/08/01 - 1990/01/01
#
# ====================================================================
#
#
#
# WARNING: parameter_check_flag is duplicated in the control file D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_cont.control.
#
#
#
# WARNING: print_debug is duplicated in the control file D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_cont.control.
#
#
# WARNING: dimension 'nlake_hrus' is not required; file is D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_par_0.params; line number 38
#
# WARNING: parameter 'hru_tlaps' is not required; file is D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_par_0.params; line number 19579
#
# WARNING: parameter 'gvr_cell_id' is not required; file is D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_par_1.params; line number 24
#
# WARNING: parameter 'mapvars_freq' is not required; file is D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_par_2.params; line number 137
#
# WARNING: parameter 'mapvars_units' is not required; file is D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_par_2.params; line number 144
#
# WARNING: parameter 'prms_warmup' is not required; file is D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_par_2.params; line number 225
#
# WARNING: parameter 'lake_hru_id' is not required; file is D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_par_3.params; line number 71217
#
# WARNING: parameter snowpack_init is used by module snowcomp but values are not
#          set in the Parameter File. Module default values are being used.
# Loading the statvar output file .....
# Finished Load the statvar output file .....
#
# ****** Par =  ssr2gw_rate, Facc = 0.5 ******
# Writing the project files .....
#
# changing model workspace...
#    D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files
# Control file is written...
# Parameters files are written...
# Data file is written...
# Modflow files are written...
# pyGSFLOW is using the following executable to run the model: D:\Training\gsflowID2447_classrepo\bin\gsflow.exe
#
# (base) D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files>D:\Training\gsflowID2447_classrepo\bin\gsflow.exe D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_cont.control
#
#                Precipitation-Runoff Modeling System (PRMS)
#                        Version 5.0.0 06/01/2018
#
#         Process            Available Modules
# --------------------------------------------------------------------
#   Basin Definition: basin
#     Cascading Flow: cascade
#   Time Series Data: obs, water_use_read, dynamic_param_read
#    Potet Solar Rad: soltab
#   Temperature Dist: temp_1sta, temp_laps, temp_dist2, climate_hru
#        Precip Dist: precip_1sta, precip_laps, precip_dist2,
#                     climate_hru
# Temp & Precip Dist: xyz_dist, ide_dist
#     Solar Rad Dist: ccsolrad, ddsolrad, climate_hru
# Transpiration Dist: transp_tindex, climate_hru, transp_frost
#       Potential ET: potet_hamon, potet_jh, potet_pan, climate_hru,
#                     potet_hs, potet_pt, potet_pm, potet_pm_sta
#       Interception: intcp
#      Snow Dynamics: snowcomp
#     Surface Runoff: srunoff_smidx, srunoff_carea
#          Soil Zone: soilzone
#        Groundwater: gwflow
# Streamflow Routing: strmflow, strmflow_in_out, muskingum,
#                     muskingum_lake
# Stream Temperature: stream_temp
#     Output Summary: basin_sum, subbasin, map_results, prms_summary,
#                     nhru_summary, nsub_summary, water_balance
#                     basin_summary, nsegment_summary
#      Preprocessing: write_climate_hru, frost_date
# --------------------------------------------------------------------
#
#
# ==========================================================================
# Please give careful consideration to fixing all ERROR and WARNING messages
# ==========================================================================
#
#
#     Active modules listed in the order in which they are called
#
#         Process                   Module                Version Date
# ====================================================================
# GSFLOW Computation Order       gsflow_prms                2018-09-26
# Basin Definition               basin                      2018-04-06
# Cascading Flow                 cascade                    2018-05-25
# Common States and Fluxes       climateflow                2018-09-19
# Potential Solar Radiation      soltab                     2016-09-09
# PRMS Set Time Variables        prms_time                  2015-03-31
# Time Series Data               obs                        2018-02-23
# Temperature Distribution       temp_1sta                  2018-01-16
# Precipitation Distribution     precip_1sta                2016-10-21
# Solar Radiation Distribution   ddsolrad                   2016-11-03
# Transpiration Distribution     transp_tindex              2015-01-06
# Potential Evapotranspiration   potet_jh                   2016-05-10
# Canopy Interception            intcp                      2018-02-26
# Snow Dynamics                  snowcomp                   2018-05-04
# Surface Runoff                 srunoff_smidx              2018-04-25
# Soil Zone Computations         soilzone                   2018-09-19
# Groundwater                    gwflow                     2018-02-26
# Streamflow Routing             strmflow                   2014-12-02
# Summary                        basin_sum                  2017-10-21
# Output Summary                 map_results                2018-04-25
#  WARNING, map_results requested with nmapOutVars equal 0
#  no map_results output is produced
# Output Summary                 subbasin                   2018-04-25
# ====================================================================
#
# Writing PRMS Water Budget File: D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_model_output.out
#
# Simulation time period: 1982/08/01 - 1990/01/01
#
# ====================================================================
#
#
#
# WARNING: parameter_check_flag is duplicated in the control file D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_cont.control.
#
#
#
# WARNING: print_debug is duplicated in the control file D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_cont.control.
#
#
# WARNING: dimension 'nlake_hrus' is not required; file is D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_par_0.params; line number 38
#
# WARNING: parameter 'hru_tlaps' is not required; file is D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_par_0.params; line number 19579
#
# WARNING: parameter 'gvr_cell_id' is not required; file is D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_par_1.params; line number 24
#
# WARNING: parameter 'mapvars_freq' is not required; file is D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_par_2.params; line number 137
#
# WARNING: parameter 'mapvars_units' is not required; file is D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_par_2.params; line number 144
#
# WARNING: parameter 'prms_warmup' is not required; file is D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_par_2.params; line number 225
#
# WARNING: parameter 'lake_hru_id' is not required; file is D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_par_3.params; line number 71217
#
# WARNING: parameter snowpack_init is used by module snowcomp but values are not
#          set in the Parameter File. Module default values are being used.
# Loading the statvar output file .....
# Finished Load the statvar output file .....
#
# ****** Par =  ssr2gw_rate, Facc = 0.75 ******
# Writing the project files .....
#
# changing model workspace...
#    D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files
# Control file is written...
# Parameters files are written...
# Data file is written...
# Modflow files are written...
# pyGSFLOW is using the following executable to run the model: D:\Training\gsflowID2447_classrepo\bin\gsflow.exe
#
# (base) D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files>D:\Training\gsflowID2447_classrepo\bin\gsflow.exe D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_cont.control
#
#                Precipitation-Runoff Modeling System (PRMS)
#                        Version 5.0.0 06/01/2018
#
#         Process            Available Modules
# --------------------------------------------------------------------
#   Basin Definition: basin
#     Cascading Flow: cascade
#   Time Series Data: obs, water_use_read, dynamic_param_read
#    Potet Solar Rad: soltab
#   Temperature Dist: temp_1sta, temp_laps, temp_dist2, climate_hru
#        Precip Dist: precip_1sta, precip_laps, precip_dist2,
#                     climate_hru
# Temp & Precip Dist: xyz_dist, ide_dist
#     Solar Rad Dist: ccsolrad, ddsolrad, climate_hru
# Transpiration Dist: transp_tindex, climate_hru, transp_frost
#       Potential ET: potet_hamon, potet_jh, potet_pan, climate_hru,
#                     potet_hs, potet_pt, potet_pm, potet_pm_sta
#       Interception: intcp
#      Snow Dynamics: snowcomp
#     Surface Runoff: srunoff_smidx, srunoff_carea
#          Soil Zone: soilzone
#        Groundwater: gwflow
# Streamflow Routing: strmflow, strmflow_in_out, muskingum,
#                     muskingum_lake
# Stream Temperature: stream_temp
#     Output Summary: basin_sum, subbasin, map_results, prms_summary,
#                     nhru_summary, nsub_summary, water_balance
#                     basin_summary, nsegment_summary
#      Preprocessing: write_climate_hru, frost_date
# --------------------------------------------------------------------
#
#
# ==========================================================================
# Please give careful consideration to fixing all ERROR and WARNING messages
# ==========================================================================
#
#
#     Active modules listed in the order in which they are called
#
#         Process                   Module                Version Date
# ====================================================================
# GSFLOW Computation Order       gsflow_prms                2018-09-26
# Basin Definition               basin                      2018-04-06
# Cascading Flow                 cascade                    2018-05-25
# Common States and Fluxes       climateflow                2018-09-19
# Potential Solar Radiation      soltab                     2016-09-09
# PRMS Set Time Variables        prms_time                  2015-03-31
# Time Series Data               obs                        2018-02-23
# Temperature Distribution       temp_1sta                  2018-01-16
# Precipitation Distribution     precip_1sta                2016-10-21
# Solar Radiation Distribution   ddsolrad                   2016-11-03
# Transpiration Distribution     transp_tindex              2015-01-06
# Potential Evapotranspiration   potet_jh                   2016-05-10
# Canopy Interception            intcp                      2018-02-26
# Snow Dynamics                  snowcomp                   2018-05-04
# Surface Runoff                 srunoff_smidx              2018-04-25
# Soil Zone Computations         soilzone                   2018-09-19
# Groundwater                    gwflow                     2018-02-26
# Streamflow Routing             strmflow                   2014-12-02
# Summary                        basin_sum                  2017-10-21
# Output Summary                 map_results                2018-04-25
#  WARNING, map_results requested with nmapOutVars equal 0
#  no map_results output is produced
# Output Summary                 subbasin                   2018-04-25
# ====================================================================
#
# Writing PRMS Water Budget File: D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_model_output.out
#
# Simulation time period: 1982/08/01 - 1990/01/01
#
# ====================================================================
#
#
#
# WARNING: parameter_check_flag is duplicated in the control file D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_cont.control.
#
#
#
# WARNING: print_debug is duplicated in the control file D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_cont.control.
#
#
# WARNING: dimension 'nlake_hrus' is not required; file is D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_par_0.params; line number 38
#
# WARNING: parameter 'hru_tlaps' is not required; file is D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_par_0.params; line number 19579
#
# WARNING: parameter 'gvr_cell_id' is not required; file is D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_par_1.params; line number 24
#
# WARNING: parameter 'mapvars_freq' is not required; file is D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_par_2.params; line number 137
#
# WARNING: parameter 'mapvars_units' is not required; file is D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_par_2.params; line number 144
#
# WARNING: parameter 'prms_warmup' is not required; file is D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_par_2.params; line number 225
#
# WARNING: parameter 'lake_hru_id' is not required; file is D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_par_3.params; line number 71217
#
# WARNING: parameter snowpack_init is used by module snowcomp but values are not
#          set in the Parameter File. Module default values are being used.
# Loading the statvar output file .....
# Finished Load the statvar output file .....
#
# ****** Par =  ssr2gw_rate, Facc = 1.0 ******
# Writing the project files .....
#
# changing model workspace...
#    D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files
# Control file is written...
# Parameters files are written...
# Data file is written...
# Modflow files are written...
# pyGSFLOW is using the following executable to run the model: D:\Training\gsflowID2447_classrepo\bin\gsflow.exe
#
# (base) D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files>D:\Training\gsflowID2447_classrepo\bin\gsflow.exe D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_cont.control
#
#                Precipitation-Runoff Modeling System (PRMS)
#                        Version 5.0.0 06/01/2018
#
#         Process            Available Modules
# --------------------------------------------------------------------
#   Basin Definition: basin
#     Cascading Flow: cascade
#   Time Series Data: obs, water_use_read, dynamic_param_read
#    Potet Solar Rad: soltab
#   Temperature Dist: temp_1sta, temp_laps, temp_dist2, climate_hru
#        Precip Dist: precip_1sta, precip_laps, precip_dist2,
#                     climate_hru
# Temp & Precip Dist: xyz_dist, ide_dist
#     Solar Rad Dist: ccsolrad, ddsolrad, climate_hru
# Transpiration Dist: transp_tindex, climate_hru, transp_frost
#       Potential ET: potet_hamon, potet_jh, potet_pan, climate_hru,
#                     potet_hs, potet_pt, potet_pm, potet_pm_sta
#       Interception: intcp
#      Snow Dynamics: snowcomp
#     Surface Runoff: srunoff_smidx, srunoff_carea
#          Soil Zone: soilzone
#        Groundwater: gwflow
# Streamflow Routing: strmflow, strmflow_in_out, muskingum,
#                     muskingum_lake
# Stream Temperature: stream_temp
#     Output Summary: basin_sum, subbasin, map_results, prms_summary,
#                     nhru_summary, nsub_summary, water_balance
#                     basin_summary, nsegment_summary
#      Preprocessing: write_climate_hru, frost_date
# --------------------------------------------------------------------
#
#
# ==========================================================================
# Please give careful consideration to fixing all ERROR and WARNING messages
# ==========================================================================
#
#
#     Active modules listed in the order in which they are called
#
#         Process                   Module                Version Date
# ====================================================================
# GSFLOW Computation Order       gsflow_prms                2018-09-26
# Basin Definition               basin                      2018-04-06
# Cascading Flow                 cascade                    2018-05-25
# Common States and Fluxes       climateflow                2018-09-19
# Potential Solar Radiation      soltab                     2016-09-09
# PRMS Set Time Variables        prms_time                  2015-03-31
# Time Series Data               obs                        2018-02-23
# Temperature Distribution       temp_1sta                  2018-01-16
# Precipitation Distribution     precip_1sta                2016-10-21
# Solar Radiation Distribution   ddsolrad                   2016-11-03
# Transpiration Distribution     transp_tindex              2015-01-06
# Potential Evapotranspiration   potet_jh                   2016-05-10
# Canopy Interception            intcp                      2018-02-26
# Snow Dynamics                  snowcomp                   2018-05-04
# Surface Runoff                 srunoff_smidx              2018-04-25
# Soil Zone Computations         soilzone                   2018-09-19
# Groundwater                    gwflow                     2018-02-26
# Streamflow Routing             strmflow                   2014-12-02
# Summary                        basin_sum                  2017-10-21
# Output Summary                 map_results                2018-04-25
#  WARNING, map_results requested with nmapOutVars equal 0
#  no map_results output is produced
# Output Summary                 subbasin                   2018-04-25
# ====================================================================
#
# Writing PRMS Water Budget File: D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_model_output.out
#
# Simulation time period: 1982/08/01 - 1990/01/01
#
# ====================================================================
#
#
#
# WARNING: parameter_check_flag is duplicated in the control file D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_cont.control.
#
#
#
# WARNING: print_debug is duplicated in the control file D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_cont.control.
#
#
# WARNING: dimension 'nlake_hrus' is not required; file is D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_par_0.params; line number 38
#
# WARNING: parameter 'hru_tlaps' is not required; file is D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_par_0.params; line number 19579
#
# WARNING: parameter 'gvr_cell_id' is not required; file is D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_par_1.params; line number 24
#
# WARNING: parameter 'mapvars_freq' is not required; file is D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_par_2.params; line number 137
#
# ...
#
#         Process                   Module                Version Date
# ====================================================================
# GSFLOW Computation Order       gsflow_prms                2018-09-26
# Basin Definition               basin                      2018-04-06
# Cascading Flow                 cascade                    2018-05-25
# Common States and Fluxes       climateflow                2018-09-19
# Potential Solar Radiation      soltab                     2016-09-09
# PRMS Set Time Variables        prms_time                  2015-03-31
# Time Series Data               obs                        2018-02-23
# Temperature Distribution       temp_1sta                  2018-01-16
# Precipitation Distribution     precip_1sta                2016-10-21
# Solar Radiation Distribution   ddsolrad                   2016-11-03
# Transpiration Distribution     transp_tindex              2015-01-06
# Potential Evapotranspiration   potet_jh                   2016-05-10
# Canopy Interception            intcp                      2018-02-26
# Snow Dynamics                  snowcomp                   2018-05-04
# Surface Runoff                 srunoff_smidx              2018-04-25
# Soil Zone Computations         soilzone                   2018-09-19
# Groundwater                    gwflow                     2018-02-26
# Streamflow Routing             strmflow                   2014-12-02
# Summary                        basin_sum                  2017-10-21
# Output Summary                 map_results                2018-04-25
#  WARNING, map_results requested with nmapOutVars equal 0
#  no map_results output is produced
# Output Summary                 subbasin                   2018-04-25
# ====================================================================
#
# Writing PRMS Water Budget File: D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_model_output.out
#
# Simulation time period: 1982/08/01 - 1990/01/01
#
# ====================================================================
#
#
#
# WARNING: parameter_check_flag is duplicated in the control file D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_cont.control.
#
#
#
# WARNING: print_debug is duplicated in the control file D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_cont.control.
#
#
# WARNING: dimension 'nlake_hrus' is not required; file is D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_par_0.params; line number 38
#
# WARNING: parameter 'hru_tlaps' is not required; file is D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_par_0.params; line number 19579
#
# WARNING: parameter 'gvr_cell_id' is not required; file is D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_par_1.params; line number 24
#
# WARNING: parameter 'mapvars_freq' is not required; file is D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_par_2.params; line number 137
#
# WARNING: parameter 'mapvars_units' is not required; file is D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_par_2.params; line number 144
#
# WARNING: parameter 'prms_warmup' is not required; file is D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_par_2.params; line number 225
#
# WARNING: parameter 'lake_hru_id' is not required; file is D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_par_3.params; line number 71217
#
# WARNING: parameter snowpack_init is used by module snowcomp but values are not
#          set in the Parameter File. Module default values are being used.
# Loading the statvar output file .....
# Finished Load the statvar output file .....
#
# ****** Par =  gwflow_coef, Facc = 1.25 ******
# Writing the project files .....
#
# changing model workspace...
#    D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files
# Control file is written...
# Parameters files are written...
# Data file is written...
# Modflow files are written...
# pyGSFLOW is using the following executable to run the model: D:\Training\gsflowID2447_classrepo\bin\gsflow.exe
#
# (base) D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files>D:\Training\gsflowID2447_classrepo\bin\gsflow.exe D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_cont.control
#
#                Precipitation-Runoff Modeling System (PRMS)
#                        Version 5.0.0 06/01/2018
#
#         Process            Available Modules
# --------------------------------------------------------------------
#   Basin Definition: basin
#     Cascading Flow: cascade
#   Time Series Data: obs, water_use_read, dynamic_param_read
#    Potet Solar Rad: soltab
#   Temperature Dist: temp_1sta, temp_laps, temp_dist2, climate_hru
#        Precip Dist: precip_1sta, precip_laps, precip_dist2,
#                     climate_hru
# Temp & Precip Dist: xyz_dist, ide_dist
#     Solar Rad Dist: ccsolrad, ddsolrad, climate_hru
# Transpiration Dist: transp_tindex, climate_hru, transp_frost
#       Potential ET: potet_hamon, potet_jh, potet_pan, climate_hru,
#                     potet_hs, potet_pt, potet_pm, potet_pm_sta
#       Interception: intcp
#      Snow Dynamics: snowcomp
#     Surface Runoff: srunoff_smidx, srunoff_carea
#          Soil Zone: soilzone
#        Groundwater: gwflow
# Streamflow Routing: strmflow, strmflow_in_out, muskingum,
#                     muskingum_lake
# Stream Temperature: stream_temp
#     Output Summary: basin_sum, subbasin, map_results, prms_summary,
#                     nhru_summary, nsub_summary, water_balance
#                     basin_summary, nsegment_summary
#      Preprocessing: write_climate_hru, frost_date
# --------------------------------------------------------------------
#
#
# ==========================================================================
# Please give careful consideration to fixing all ERROR and WARNING messages
# ==========================================================================
#
#
#     Active modules listed in the order in which they are called
#
#         Process                   Module                Version Date
# ====================================================================
# GSFLOW Computation Order       gsflow_prms                2018-09-26
# Basin Definition               basin                      2018-04-06
# Cascading Flow                 cascade                    2018-05-25
# Common States and Fluxes       climateflow                2018-09-19
# Potential Solar Radiation      soltab                     2016-09-09
# PRMS Set Time Variables        prms_time                  2015-03-31
# Time Series Data               obs                        2018-02-23
# Temperature Distribution       temp_1sta                  2018-01-16
# Precipitation Distribution     precip_1sta                2016-10-21
# Solar Radiation Distribution   ddsolrad                   2016-11-03
# Transpiration Distribution     transp_tindex              2015-01-06
# Potential Evapotranspiration   potet_jh                   2016-05-10
# Canopy Interception            intcp                      2018-02-26
# Snow Dynamics                  snowcomp                   2018-05-04
# Surface Runoff                 srunoff_smidx              2018-04-25
# Soil Zone Computations         soilzone                   2018-09-19
# Groundwater                    gwflow                     2018-02-26
# Streamflow Routing             strmflow                   2014-12-02
# Summary                        basin_sum                  2017-10-21
# Output Summary                 map_results                2018-04-25
#  WARNING, map_results requested with nmapOutVars equal 0
#  no map_results output is produced
# Output Summary                 subbasin                   2018-04-25
# ====================================================================
# Writing PRMS Water Budget File: D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_model_output.out
#
# Simulation time period: 1982/08/01 - 1990/01/01
#
# ====================================================================
#
#
#
# WARNING: parameter_check_flag is duplicated in the control file D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_cont.control.
#
#
#
# WARNING: print_debug is duplicated in the control file D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_cont.control.
#
#
# WARNING: dimension 'nlake_hrus' is not required; file is D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_par_0.params; line number 38
#
# WARNING: parameter 'hru_tlaps' is not required; file is D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_par_0.params; line number 19579
#
# WARNING: parameter 'gvr_cell_id' is not required; file is D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_par_1.params; line number 24
#
# WARNING: parameter 'mapvars_freq' is not required; file is D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_par_2.params; line number 137
#
# WARNING: parameter 'mapvars_units' is not required; file is D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_par_2.params; line number 144
#
# WARNING: parameter 'prms_warmup' is not required; file is D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_par_2.params; line number 225
#
# WARNING: parameter 'lake_hru_id' is not required; file is D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_par_3.params; line number 71217
#
# WARNING: parameter snowpack_init is used by module snowcomp but values are not
#          set in the Parameter File. Module default values are being used.
# Loading the statvar output file .....
# Finished Load the statvar output file .....
#
# ****** Par =  gwflow_coef, Facc = 1.5 ******
# Writing the project files .....
#
# changing model workspace...
#    D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files
# Control file is written...
# Parameters files are written...
# Data file is written...
# Modflow files are written...
# pyGSFLOW is using the following executable to run the model: D:\Training\gsflowID2447_classrepo\bin\gsflow.exe
#
# (base) D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files>D:\Training\gsflowID2447_classrepo\bin\gsflow.exe D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_cont.control
#
#                Precipitation-Runoff Modeling System (PRMS)
#                        Version 5.0.0 06/01/2018
#
#         Process            Available Modules
# --------------------------------------------------------------------
#   Basin Definition: basin
#     Cascading Flow: cascade
#   Time Series Data: obs, water_use_read, dynamic_param_read
#    Potet Solar Rad: soltab
#   Temperature Dist: temp_1sta, temp_laps, temp_dist2, climate_hru
#        Precip Dist: precip_1sta, precip_laps, precip_dist2,
#                     climate_hru
# Temp & Precip Dist: xyz_dist, ide_dist
#     Solar Rad Dist: ccsolrad, ddsolrad, climate_hru
# Transpiration Dist: transp_tindex, climate_hru, transp_frost
#       Potential ET: potet_hamon, potet_jh, potet_pan, climate_hru,
#                     potet_hs, potet_pt, potet_pm, potet_pm_sta
#       Interception: intcp
#      Snow Dynamics: snowcomp
#     Surface Runoff: srunoff_smidx, srunoff_carea
#          Soil Zone: soilzone
#        Groundwater: gwflow
# Streamflow Routing: strmflow, strmflow_in_out, muskingum,
#                     muskingum_lake
# Stream Temperature: stream_temp
#     Output Summary: basin_sum, subbasin, map_results, prms_summary,
#                     nhru_summary, nsub_summary, water_balance
#                     basin_summary, nsegment_summary
#      Preprocessing: write_climate_hru, frost_date
# --------------------------------------------------------------------
#
#
# ==========================================================================
# Please give careful consideration to fixing all ERROR and WARNING messages
# ==========================================================================
#
#
#     Active modules listed in the order in which they are called
#
#         Process                   Module                Version Date
# ====================================================================
# GSFLOW Computation Order       gsflow_prms                2018-09-26
# Basin Definition               basin                      2018-04-06
# Cascading Flow                 cascade                    2018-05-25
# Common States and Fluxes       climateflow                2018-09-19
# Potential Solar Radiation      soltab                     2016-09-09
# PRMS Set Time Variables        prms_time                  2015-03-31
# Time Series Data               obs                        2018-02-23
# Temperature Distribution       temp_1sta                  2018-01-16
# Precipitation Distribution     precip_1sta                2016-10-21
# Solar Radiation Distribution   ddsolrad                   2016-11-03
# Transpiration Distribution     transp_tindex              2015-01-06
# Potential Evapotranspiration   potet_jh                   2016-05-10
# Canopy Interception            intcp                      2018-02-26
# Snow Dynamics                  snowcomp                   2018-05-04
# Surface Runoff                 srunoff_smidx              2018-04-25
# Soil Zone Computations         soilzone                   2018-09-19
# Groundwater                    gwflow                     2018-02-26
# Streamflow Routing             strmflow                   2014-12-02
# Summary                        basin_sum                  2017-10-21
# Output Summary                 map_results                2018-04-25
#  WARNING, map_results requested with nmapOutVars equal 0
#  no map_results output is produced
# Output Summary                 subbasin                   2018-04-25
# ====================================================================
#
# Writing PRMS Water Budget File: D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_model_output.out
#
# Simulation time period: 1982/08/01 - 1990/01/01
#
# ====================================================================
#
#
#
# WARNING: parameter_check_flag is duplicated in the control file D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_cont.control.
#
#
#
# WARNING: print_debug is duplicated in the control file D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_cont.control.
#
#
# WARNING: dimension 'nlake_hrus' is not required; file is D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_par_0.params; line number 38
#
# WARNING: parameter 'hru_tlaps' is not required; file is D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_par_0.params; line number 19579
#
# WARNING: parameter 'gvr_cell_id' is not required; file is D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_par_1.params; line number 24
#
# WARNING: parameter 'mapvars_freq' is not required; file is D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_par_2.params; line number 137
#
# WARNING: parameter 'mapvars_units' is not required; file is D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_par_2.params; line number 144
#
# WARNING: parameter 'prms_warmup' is not required; file is D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_par_2.params; line number 225
#
# WARNING: parameter 'lake_hru_id' is not required; file is D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_par_3.params; line number 71217
#
# WARNING: parameter snowpack_init is used by module snowcomp but values are not
#          set in the Parameter File. Module default values are being used.
# Loading the statvar output file .....
# Finished Load the statvar output file .....
# Wall time: 2min 15s

# %%
plt.figure(figsize=(15,8))
for par in all_sens.keys():
    plt.plot(factors, all_sens[par], label = par, marker=11 )
plt.ylabel("Average Stream Flow (cfs)")
plt.xlabel("Scaling Factor")
plt.legend()

# %% [markdown]
# ## (4) Simple Calibration
#
#
# ### (4.a) Error Evaluation

# %%
# Before we start let us load the model
control_file = r"../models_data/gsflow/saghen_new_cont.control"
gs = Gsflow(control_file=control_file)
gs.gsflow_exe = os.path.abspath(r"../../bin/gsflow.exe")
gs.control.set_values("model_mode", ['PRMS'])
gs.control.set_values("print_debug", [-1]) # this will turn off screen printout and reduce output to the notebook
gs.control.set_values(name='end_time', values=[1990,1,1,0,0,0])
Params = gs.prms.parameters

gs.write_input(workspace=r"./prms_files")              # write input
gs.run_model()                                         # run the model
gs.prms.get_statVar()  
gs.run_model()
# Out:
# PyGSFLOW ------ V0.0
# Control file is loaded
# Working on loading PRMS model ...
# Parameters will be read from a file/ files...
# Work on loadind the parameter files .....
# Prms model is loaded .....
# Working on loading MODFLOW files ....
#    loading iuzfbnd array...
#    loading irunbnd array...
#    loading vks array...
#    loading eps array...
#    loading thts array...
# stress period 1:
#    loading finf array...
# stress period 2:
# MOSFLOW files are loaded ...
# Writing the project files .....
#
# changing model workspace...
#    D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files
# Control file is written...
# Parameters files are written...
# Data file is written...
# Modflow files are written...
# pyGSFLOW is using the following executable to run the model: D:\Training\gsflowID2447_classrepo\bin\gsflow.exe
#
# (base) D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files>D:\Training\gsflowID2447_classrepo\bin\gsflow.exe D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_cont.control
#
#                Precipitation-Runoff Modeling System (PRMS)
#                        Version 5.0.0 06/01/2018
#
#         Process            Available Modules
# --------------------------------------------------------------------
#   Basin Definition: basin
#     Cascading Flow: cascade
#   Time Series Data: obs, water_use_read, dynamic_param_read
#    Potet Solar Rad: soltab
#   Temperature Dist: temp_1sta, temp_laps, temp_dist2, climate_hru
#        Precip Dist: precip_1sta, precip_laps, precip_dist2,
#                     climate_hru
# Temp & Precip Dist: xyz_dist, ide_dist
#     Solar Rad Dist: ccsolrad, ddsolrad, climate_hru
# Transpiration Dist: transp_tindex, climate_hru, transp_frost
#       Potential ET: potet_hamon, potet_jh, potet_pan, climate_hru,
#                     potet_hs, potet_pt, potet_pm, potet_pm_sta
#       Interception: intcp
#      Snow Dynamics: snowcomp
#     Surface Runoff: srunoff_smidx, srunoff_carea
#          Soil Zone: soilzone
#        Groundwater: gwflow
# Streamflow Routing: strmflow, strmflow_in_out, muskingum,
#                     muskingum_lake
# Stream Temperature: stream_temp
#     Output Summary: basin_sum, subbasin, map_results, prms_summary,
#                     nhru_summary, nsub_summary, water_balance
#                     basin_summary, nsegment_summary
#      Preprocessing: write_climate_hru, frost_date
# --------------------------------------------------------------------
#
#
# ==========================================================================
# Please give careful consideration to fixing all ERROR and WARNING messages
# ==========================================================================
#
#
#     Active modules listed in the order in which they are called
#
#         Process                   Module                Version Date
# ====================================================================
# GSFLOW Computation Order       gsflow_prms                2018-09-26
# Basin Definition               basin                      2018-04-06
# Cascading Flow                 cascade                    2018-05-25
# Common States and Fluxes       climateflow                2018-09-19
# Potential Solar Radiation      soltab                     2016-09-09
# PRMS Set Time Variables        prms_time                  2015-03-31
# Time Series Data               obs                        2018-02-23
# Temperature Distribution       temp_1sta                  2018-01-16
# Precipitation Distribution     precip_1sta                2016-10-21
# Solar Radiation Distribution   ddsolrad                   2016-11-03
# Transpiration Distribution     transp_tindex              2015-01-06
# Potential Evapotranspiration   potet_jh                   2016-05-10
# Canopy Interception            intcp                      2018-02-26
# Snow Dynamics                  snowcomp                   2018-05-04
# Surface Runoff                 srunoff_smidx              2018-04-25
# Soil Zone Computations         soilzone                   2018-09-19
# Groundwater                    gwflow                     2018-02-26
# Streamflow Routing             strmflow                   2014-12-02
# Summary                        basin_sum                  2017-10-21
# Output Summary                 map_results                2018-04-25
#  WARNING, map_results requested with nmapOutVars equal 0
#  no map_results output is produced
# Output Summary                 subbasin                   2018-04-25
# ====================================================================
#
# Writing PRMS Water Budget File: D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_model_output.out
#
# Simulation time period: 1982/08/01 - 1990/01/01
#
# ====================================================================
#
#
#
# WARNING: parameter_check_flag is duplicated in the control file D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_cont.control.
#
#
#
# WARNING: print_debug is duplicated in the control file D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_cont.control.
#
#
# WARNING: dimension 'nlake_hrus' is not required; file is D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_par_0.params; line number 38
#
# WARNING: parameter 'hru_tlaps' is not required; file is D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_par_0.params; line number 19579
#
# WARNING: parameter 'gvr_cell_id' is not required; file is D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_par_1.params; line number 24
#
# WARNING: parameter 'mapvars_freq' is not required; file is D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_par_2.params; line number 137
#
# WARNING: parameter 'mapvars_units' is not required; file is D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_par_2.params; line number 144
#
# WARNING: parameter 'prms_warmup' is not required; file is D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_par_2.params; line number 225
#
# WARNING: parameter 'lake_hru_id' is not required; file is D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_par_3.params; line number 71217
#
# WARNING: parameter snowpack_init is used by module snowcomp but values are not
#          set in the Parameter File. Module default values are being used.
# Loading the statvar output file .....
# Finished Load the statvar output file .....
# pyGSFLOW is using the following executable to run the model: D:\Training\gsflowID2447_classrepo\bin\gsflow.exe
#
# (base) D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files>D:\Training\gsflowID2447_classrepo\bin\gsflow.exe D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_cont.control
#
#                Precipitation-Runoff Modeling System (PRMS)
#                        Version 5.0.0 06/01/2018
#
#         Process            Available Modules
# --------------------------------------------------------------------
#   Basin Definition: basin
#     Cascading Flow: cascade
#   Time Series Data: obs, water_use_read, dynamic_param_read
#    Potet Solar Rad: soltab
#   Temperature Dist: temp_1sta, temp_laps, temp_dist2, climate_hru
#        Precip Dist: precip_1sta, precip_laps, precip_dist2,
#                     climate_hru
# Temp & Precip Dist: xyz_dist, ide_dist
#     Solar Rad Dist: ccsolrad, ddsolrad, climate_hru
# Transpiration Dist: transp_tindex, climate_hru, transp_frost
#       Potential ET: potet_hamon, potet_jh, potet_pan, climate_hru,
#                     potet_hs, potet_pt, potet_pm, potet_pm_sta
#       Interception: intcp
#      Snow Dynamics: snowcomp
#     Surface Runoff: srunoff_smidx, srunoff_carea
#          Soil Zone: soilzone
#        Groundwater: gwflow
# Streamflow Routing: strmflow, strmflow_in_out, muskingum,
#                     muskingum_lake
# Stream Temperature: stream_temp
#     Output Summary: basin_sum, subbasin, map_results, prms_summary,
#                     nhru_summary, nsub_summary, water_balance
#                     basin_summary, nsegment_summary
#      Preprocessing: write_climate_hru, frost_date
# --------------------------------------------------------------------
#
#
# ==========================================================================
# Please give careful consideration to fixing all ERROR and WARNING messages
# ==========================================================================
#
#
#     Active modules listed in the order in which they are called
#
#         Process                   Module                Version Date
# ====================================================================
# GSFLOW Computation Order       gsflow_prms                2018-09-26
# Basin Definition               basin                      2018-04-06
# Cascading Flow                 cascade                    2018-05-25
# Common States and Fluxes       climateflow                2018-09-19
# Potential Solar Radiation      soltab                     2016-09-09
# PRMS Set Time Variables        prms_time                  2015-03-31
# Time Series Data               obs                        2018-02-23
# Temperature Distribution       temp_1sta                  2018-01-16
# Precipitation Distribution     precip_1sta                2016-10-21
# Solar Radiation Distribution   ddsolrad                   2016-11-03
# Transpiration Distribution     transp_tindex              2015-01-06
# Potential Evapotranspiration   potet_jh                   2016-05-10
# Canopy Interception            intcp                      2018-02-26
# Snow Dynamics                  snowcomp                   2018-05-04
# Surface Runoff                 srunoff_smidx              2018-04-25
# Soil Zone Computations         soilzone                   2018-09-19
# Groundwater                    gwflow                     2018-02-26
# Streamflow Routing             strmflow                   2014-12-02
# Summary                        basin_sum                  2017-10-21
# Output Summary                 map_results                2018-04-25
#  WARNING, map_results requested with nmapOutVars equal 0
#  no map_results output is produced
# Output Summary                 subbasin                   2018-04-25
# ====================================================================
# Writing PRMS Water Budget File: D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_model_output.out
#
# Simulation time period: 1982/08/01 - 1990/01/01
#
# ====================================================================
#
#
#
# WARNING: parameter_check_flag is duplicated in the control file D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_cont.control.
#
#
#
# WARNING: print_debug is duplicated in the control file D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_cont.control.
#
#
# WARNING: dimension 'nlake_hrus' is not required; file is D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_par_0.params; line number 38
#
# WARNING: parameter 'hru_tlaps' is not required; file is D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_par_0.params; line number 19579
#
# WARNING: parameter 'gvr_cell_id' is not required; file is D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_par_1.params; line number 24
#
# WARNING: parameter 'mapvars_freq' is not required; file is D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_par_2.params; line number 137
#
# WARNING: parameter 'mapvars_units' is not required; file is D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_par_2.params; line number 144
#
# WARNING: parameter 'prms_warmup' is not required; file is D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_par_2.params; line number 225
#
# WARNING: parameter 'lake_hru_id' is not required; file is D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_par_3.params; line number 71217
#
# WARNING: parameter snowpack_init is used by module snowcomp but values are not
#          set in the Parameter File. Module default values are being used.

# %% [markdown]
# #### Compare measurements and simulations

# %%
# Dialy Stream flow
# get measurments within the simulation period...
meas_data = gs.prms.Data.data_df  # Data object in PRMS
mask = np.logical_and(meas_data['Date']>=pd.Timestamp('1982-08-01'),  meas_data['Date']<=pd.Timestamp('1990-01-11'))
measure_data = gs.prms.Data.data_df[mask]

# get simulation results
simData = gs.prms.stat.stat_df  # Results from StatVar file

# plot simulated vs. measured flow
ax = measure_data.plot(x= 'Date' , y= 'runoff_0', color = 'r', label = 'Measured')
simData.plot(ax=ax, x= 'Date' , y= 'basin_cfs_1', color = 'b', label = 'Simulated', figsize = (15,8))
plt.legend()

# %% [markdown]
# #### Monthly Stream flow

# %%
# Monthly average for streamflow measurements
monthly_meas = measure_data.groupby([measure_data.Date.dt.year, measure_data.Date.dt.month] ).mean()
monthly_sim = simData.groupby([simData.Date.dt.year,simData.Date.dt.month] ).mean()

# Plots
plt.figure(figsize=(15,7))

plt.subplot(1,2,1)
plt.plot(monthly_meas['runoff_0'].values, 'r', label = 'Measured')
plt.plot(monthly_sim['basin_cfs_1'].values, 'b', label = 'Simulated')
plt.xlabel("Month Number after starting Year (1982)")
plt.ylabel("Flow (cfs)")
plt.legend()

plt.subplot(1,2,2)
plt.scatter(monthly_meas['runoff_0'].values,monthly_sim['basin_cfs_1'].values ); plt.plot([0,140],[0,140],'r')
plt.xlabel("Measured flow (cfs)")
plt.ylabel("Simulated flow (cfs)")
# Out:
# Text(0,0.5,'Simulated flow (cfs)')

# %% [markdown]
# ### (4.b) Compute Error Metric

# %%
def calculate_error(gs):
    """
    This function calculates mean squared error for simulated stream flow.
    """
    meas_data = gs.prms.Data.data_df # get measured data
    # Get data for simulated period
    mask = np.logical_and(meas_data['Date']>=pd.Timestamp('1982-08-01'),  meas_data['Date']<=pd.Timestamp('1990-01-01'))    
    measure_data = gs.prms.Data.data_df[mask]
    
    # get simulated values
    simData = gs.prms.stat.stat_df
    
    # compute error
    err = simData['basin_cfs_1'].values - measure_data['runoff_0'].values
    # compute mean squared error
    rmse = (np.mean(np.power(err, 2.0)))**0.5
    return rmse

# %% [markdown]
# ### (4.c) Simple Calibration
# Change one parameter at a time. This method can be useful when input parameters are independent.
# <img src = ".\figures\calibration_cycle.png">

# %%
orig_params.keys()
# Out:
# ['gwflow_coef', 'snarea_curve', 'ssr2gw_rate']

# %%
# %%time
parameters = ['gwflow_coef', 'snarea_curve', 'ssr2gw_rate']
factors = [ 0.75, 1.0, 1.25, 1.5, 1.75, 2.0, 2.25]
all_errors = {}
for par in parameters:    
    errors = []
    for facc in factors:
        print("\n****** Par =  {}, Facc = {} ****** ".format(par, facc))
        
        # change input parameters
        Params.set_values(name=par, values = orig_params[par]*facc) # change the parameter
        
        # write input files
        gs.write_input(workspace=r"./prms_files")              # write input
        
        # run the model
        gs.run_model()                                              # run the model
        
        # load the results
        gs.prms.get_statVar()                                       # load load results from Statvar 
        
        # calculate the error
        err = calculate_error(gs)                                    # compute the mean square error
        errors.append(err)
        
    all_errors[par] = errors
    Params.set_values(name=par, values = orig_params[par])
# Out:
# ****** Par =  gwflow_coef, Facc = 0.75 ******
# Writing the project files .....
#
# changing model workspace...
#    D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files
# Control file is written...
# Parameters files are written...
# Data file is written...
# Modflow files are written...
# pyGSFLOW is using the following executable to run the model: D:\Training\gsflowID2447_classrepo\bin\gsflow.exe
#
# (base) D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files>D:\Training\gsflowID2447_classrepo\bin\gsflow.exe D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_cont.control
#
#                Precipitation-Runoff Modeling System (PRMS)
#                        Version 5.0.0 06/01/2018
#
#         Process            Available Modules
# --------------------------------------------------------------------
#   Basin Definition: basin
#     Cascading Flow: cascade
#   Time Series Data: obs, water_use_read, dynamic_param_read
#    Potet Solar Rad: soltab
#   Temperature Dist: temp_1sta, temp_laps, temp_dist2, climate_hru
#        Precip Dist: precip_1sta, precip_laps, precip_dist2,
#                     climate_hru
# Temp & Precip Dist: xyz_dist, ide_dist
#     Solar Rad Dist: ccsolrad, ddsolrad, climate_hru
# Transpiration Dist: transp_tindex, climate_hru, transp_frost
#       Potential ET: potet_hamon, potet_jh, potet_pan, climate_hru,
#                     potet_hs, potet_pt, potet_pm, potet_pm_sta
#       Interception: intcp
#      Snow Dynamics: snowcomp
#     Surface Runoff: srunoff_smidx, srunoff_carea
#          Soil Zone: soilzone
#        Groundwater: gwflow
# Streamflow Routing: strmflow, strmflow_in_out, muskingum,
#                     muskingum_lake
# Stream Temperature: stream_temp
#     Output Summary: basin_sum, subbasin, map_results, prms_summary,
#                     nhru_summary, nsub_summary, water_balance
#                     basin_summary, nsegment_summary
#      Preprocessing: write_climate_hru, frost_date
# --------------------------------------------------------------------
#
#
# ==========================================================================
# Please give careful consideration to fixing all ERROR and WARNING messages
# ==========================================================================
#
#
#     Active modules listed in the order in which they are called
#
#         Process                   Module                Version Date
# ====================================================================
# GSFLOW Computation Order       gsflow_prms                2018-09-26
# Basin Definition               basin                      2018-04-06
# Cascading Flow                 cascade                    2018-05-25
# Common States and Fluxes       climateflow                2018-09-19
# Potential Solar Radiation      soltab                     2016-09-09
# PRMS Set Time Variables        prms_time                  2015-03-31
# Time Series Data               obs                        2018-02-23
# Temperature Distribution       temp_1sta                  2018-01-16
# Precipitation Distribution     precip_1sta                2016-10-21
# Solar Radiation Distribution   ddsolrad                   2016-11-03
# Transpiration Distribution     transp_tindex              2015-01-06
# Potential Evapotranspiration   potet_jh                   2016-05-10
# Canopy Interception            intcp                      2018-02-26
# Snow Dynamics                  snowcomp                   2018-05-04
# Surface Runoff                 srunoff_smidx              2018-04-25
# Soil Zone Computations         soilzone                   2018-09-19
# Groundwater                    gwflow                     2018-02-26
# Streamflow Routing             strmflow                   2014-12-02
# Summary                        basin_sum                  2017-10-21
# Output Summary                 map_results                2018-04-25
#  WARNING, map_results requested with nmapOutVars equal 0
#  no map_results output is produced
# Output Summary                 subbasin                   2018-04-25
# ====================================================================
#
# Writing PRMS Water Budget File: D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_model_output.out
#
# Simulation time period: 1982/08/01 - 1990/01/01
#
# ====================================================================
#
#
#
# WARNING: parameter_check_flag is duplicated in the control file D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_cont.control.
#
#
#
# WARNING: print_debug is duplicated in the control file D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_cont.control.
#
#
# WARNING: dimension 'nlake_hrus' is not required; file is D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_par_0.params; line number 38
#
# WARNING: parameter 'hru_tlaps' is not required; file is D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_par_0.params; line number 19579
#
# WARNING: parameter 'gvr_cell_id' is not required; file is D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_par_1.params; line number 24
#
# WARNING: parameter 'mapvars_freq' is not required; file is D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_par_2.params; line number 137
#
# WARNING: parameter 'mapvars_units' is not required; file is D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_par_2.params; line number 144
#
# WARNING: parameter 'prms_warmup' is not required; file is D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_par_2.params; line number 225
#
# WARNING: parameter 'lake_hru_id' is not required; file is D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_par_3.params; line number 71217
#
# WARNING: parameter snowpack_init is used by module snowcomp but values are not
#          set in the Parameter File. Module default values are being used.
# Loading the statvar output file .....
# Finished Load the statvar output file .....
#
# ****** Par =  gwflow_coef, Facc = 1.0 ******
# Writing the project files .....
#
# changing model workspace...
#    D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files
# Control file is written...
# Parameters files are written...
# Data file is written...
# Modflow files are written...
# pyGSFLOW is using the following executable to run the model: D:\Training\gsflowID2447_classrepo\bin\gsflow.exe
#
# (base) D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files>D:\Training\gsflowID2447_classrepo\bin\gsflow.exe D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_cont.control
#
#                Precipitation-Runoff Modeling System (PRMS)
#                        Version 5.0.0 06/01/2018
#
#         Process            Available Modules
# --------------------------------------------------------------------
#   Basin Definition: basin
#     Cascading Flow: cascade
#   Time Series Data: obs, water_use_read, dynamic_param_read
#    Potet Solar Rad: soltab
#   Temperature Dist: temp_1sta, temp_laps, temp_dist2, climate_hru
#        Precip Dist: precip_1sta, precip_laps, precip_dist2,
#                     climate_hru
# Temp & Precip Dist: xyz_dist, ide_dist
#     Solar Rad Dist: ccsolrad, ddsolrad, climate_hru
# Transpiration Dist: transp_tindex, climate_hru, transp_frost
#       Potential ET: potet_hamon, potet_jh, potet_pan, climate_hru,
#                     potet_hs, potet_pt, potet_pm, potet_pm_sta
#       Interception: intcp
#      Snow Dynamics: snowcomp
#     Surface Runoff: srunoff_smidx, srunoff_carea
#          Soil Zone: soilzone
#        Groundwater: gwflow
# Streamflow Routing: strmflow, strmflow_in_out, muskingum,
#                     muskingum_lake
# Stream Temperature: stream_temp
#     Output Summary: basin_sum, subbasin, map_results, prms_summary,
#                     nhru_summary, nsub_summary, water_balance
#                     basin_summary, nsegment_summary
#      Preprocessing: write_climate_hru, frost_date
# --------------------------------------------------------------------
#
#
# ==========================================================================
# Please give careful consideration to fixing all ERROR and WARNING messages
# ==========================================================================
#
#
#     Active modules listed in the order in which they are called
#
#         Process                   Module                Version Date
# ====================================================================
# GSFLOW Computation Order       gsflow_prms                2018-09-26
# Basin Definition               basin                      2018-04-06
# Cascading Flow                 cascade                    2018-05-25
# Common States and Fluxes       climateflow                2018-09-19
# Potential Solar Radiation      soltab                     2016-09-09
# PRMS Set Time Variables        prms_time                  2015-03-31
# Time Series Data               obs                        2018-02-23
# Temperature Distribution       temp_1sta                  2018-01-16
# Precipitation Distribution     precip_1sta                2016-10-21
# Solar Radiation Distribution   ddsolrad                   2016-11-03
# Transpiration Distribution     transp_tindex              2015-01-06
# Potential Evapotranspiration   potet_jh                   2016-05-10
# Canopy Interception            intcp                      2018-02-26
# Snow Dynamics                  snowcomp                   2018-05-04
# Surface Runoff                 srunoff_smidx              2018-04-25
# Soil Zone Computations         soilzone                   2018-09-19
# Groundwater                    gwflow                     2018-02-26
# Streamflow Routing             strmflow                   2014-12-02
# Summary                        basin_sum                  2017-10-21
# Output Summary                 map_results                2018-04-25
#  WARNING, map_results requested with nmapOutVars equal 0
#  no map_results output is produced
# Output Summary                 subbasin                   2018-04-25
# ====================================================================
# Writing PRMS Water Budget File: D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_model_output.out
#
# Simulation time period: 1982/08/01 - 1990/01/01
#
# ====================================================================
#
#
#
# WARNING: parameter_check_flag is duplicated in the control file D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_cont.control.
#
#
#
# WARNING: print_debug is duplicated in the control file D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_cont.control.
#
#
# WARNING: dimension 'nlake_hrus' is not required; file is D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_par_0.params; line number 38
#
# WARNING: parameter 'hru_tlaps' is not required; file is D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_par_0.params; line number 19579
#
# WARNING: parameter 'gvr_cell_id' is not required; file is D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_par_1.params; line number 24
#
# WARNING: parameter 'mapvars_freq' is not required; file is D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_par_2.params; line number 137
#
# WARNING: parameter 'mapvars_units' is not required; file is D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_par_2.params; line number 144
#
# WARNING: parameter 'prms_warmup' is not required; file is D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_par_2.params; line number 225
#
# WARNING: parameter 'lake_hru_id' is not required; file is D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_par_3.params; line number 71217
#
# WARNING: parameter snowpack_init is used by module snowcomp but values are not
#          set in the Parameter File. Module default values are being used.
# Loading the statvar output file .....
# Finished Load the statvar output file .....
#
# ****** Par =  gwflow_coef, Facc = 1.25 ******
# Writing the project files .....
#
# changing model workspace...
#    D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files
# Control file is written...
# Parameters files are written...
# Data file is written...
# Modflow files are written...
# pyGSFLOW is using the following executable to run the model: D:\Training\gsflowID2447_classrepo\bin\gsflow.exe
#
# (base) D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files>D:\Training\gsflowID2447_classrepo\bin\gsflow.exe D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_cont.control
#
#                Precipitation-Runoff Modeling System (PRMS)
#                        Version 5.0.0 06/01/2018
#
#         Process            Available Modules
# --------------------------------------------------------------------
#   Basin Definition: basin
#     Cascading Flow: cascade
#   Time Series Data: obs, water_use_read, dynamic_param_read
#    Potet Solar Rad: soltab
#   Temperature Dist: temp_1sta, temp_laps, temp_dist2, climate_hru
#        Precip Dist: precip_1sta, precip_laps, precip_dist2,
#                     climate_hru
# Temp & Precip Dist: xyz_dist, ide_dist
#     Solar Rad Dist: ccsolrad, ddsolrad, climate_hru
# Transpiration Dist: transp_tindex, climate_hru, transp_frost
#       Potential ET: potet_hamon, potet_jh, potet_pan, climate_hru,
#                     potet_hs, potet_pt, potet_pm, potet_pm_sta
#       Interception: intcp
#      Snow Dynamics: snowcomp
#     Surface Runoff: srunoff_smidx, srunoff_carea
#          Soil Zone: soilzone
#        Groundwater: gwflow
# Streamflow Routing: strmflow, strmflow_in_out, muskingum,
#                     muskingum_lake
# Stream Temperature: stream_temp
#     Output Summary: basin_sum, subbasin, map_results, prms_summary,
#                     nhru_summary, nsub_summary, water_balance
#                     basin_summary, nsegment_summary
#      Preprocessing: write_climate_hru, frost_date
# --------------------------------------------------------------------
#
#
# ==========================================================================
# Please give careful consideration to fixing all ERROR and WARNING messages
# ==========================================================================
#
#
#     Active modules listed in the order in which they are called
#
#         Process                   Module                Version Date
# ====================================================================
# GSFLOW Computation Order       gsflow_prms                2018-09-26
# Basin Definition               basin                      2018-04-06
# Cascading Flow                 cascade                    2018-05-25
# Common States and Fluxes       climateflow                2018-09-19
# Potential Solar Radiation      soltab                     2016-09-09
# PRMS Set Time Variables        prms_time                  2015-03-31
# Time Series Data               obs                        2018-02-23
# Temperature Distribution       temp_1sta                  2018-01-16
# Precipitation Distribution     precip_1sta                2016-10-21
# Solar Radiation Distribution   ddsolrad                   2016-11-03
# Transpiration Distribution     transp_tindex              2015-01-06
# Potential Evapotranspiration   potet_jh                   2016-05-10
# Canopy Interception            intcp                      2018-02-26
# Snow Dynamics                  snowcomp                   2018-05-04
# Surface Runoff                 srunoff_smidx              2018-04-25
# Soil Zone Computations         soilzone                   2018-09-19
# Groundwater                    gwflow                     2018-02-26
# Streamflow Routing             strmflow                   2014-12-02
# Summary                        basin_sum                  2017-10-21
# Output Summary                 map_results                2018-04-25
#  WARNING, map_results requested with nmapOutVars equal 0
#  no map_results output is produced
# Output Summary                 subbasin                   2018-04-25
# ====================================================================
#
# Writing PRMS Water Budget File: D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_model_output.out
#
# Simulation time period: 1982/08/01 - 1990/01/01
#
# ====================================================================
#
#
#
# WARNING: parameter_check_flag is duplicated in the control file D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_cont.control.
#
#
#
# WARNING: print_debug is duplicated in the control file D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_cont.control.
#
#
# WARNING: dimension 'nlake_hrus' is not required; file is D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_par_0.params; line number 38
#
# WARNING: parameter 'hru_tlaps' is not required; file is D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_par_0.params; line number 19579
#
# WARNING: parameter 'gvr_cell_id' is not required; file is D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_par_1.params; line number 24
#
# WARNING: parameter 'mapvars_freq' is not required; file is D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_par_2.params; line number 137
#
# WARNING: parameter 'mapvars_units' is not required; file is D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_par_2.params; line number 144
#
# WARNING: parameter 'prms_warmup' is not required; file is D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_par_2.params; line number 225
#
# WARNING: parameter 'lake_hru_id' is not required; file is D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_par_3.params; line number 71217
#
# WARNING: parameter snowpack_init is used by module snowcomp but values are not
#          set in the Parameter File. Module default values are being used.
# Loading the statvar output file .....
# Finished Load the statvar output file .....
#
# ****** Par =  gwflow_coef, Facc = 1.5 ******
# Writing the project files .....
#
# changing model workspace...
#    D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files
# Control file is written...
# Parameters files are written...
# Data file is written...
# Modflow files are written...
# pyGSFLOW is using the following executable to run the model: D:\Training\gsflowID2447_classrepo\bin\gsflow.exe
#
# (base) D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files>D:\Training\gsflowID2447_classrepo\bin\gsflow.exe D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_cont.control
#
#                Precipitation-Runoff Modeling System (PRMS)
#                        Version 5.0.0 06/01/2018
#
#         Process            Available Modules
# --------------------------------------------------------------------
#   Basin Definition: basin
#     Cascading Flow: cascade
#   Time Series Data: obs, water_use_read, dynamic_param_read
#    Potet Solar Rad: soltab
#   Temperature Dist: temp_1sta, temp_laps, temp_dist2, climate_hru
#        Precip Dist: precip_1sta, precip_laps, precip_dist2,
#                     climate_hru
# Temp & Precip Dist: xyz_dist, ide_dist
#     Solar Rad Dist: ccsolrad, ddsolrad, climate_hru
# Transpiration Dist: transp_tindex, climate_hru, transp_frost
#       Potential ET: potet_hamon, potet_jh, potet_pan, climate_hru,
#                     potet_hs, potet_pt, potet_pm, potet_pm_sta
#       Interception: intcp
#      Snow Dynamics: snowcomp
#     Surface Runoff: srunoff_smidx, srunoff_carea
#          Soil Zone: soilzone
#        Groundwater: gwflow
# Streamflow Routing: strmflow, strmflow_in_out, muskingum,
#                     muskingum_lake
# Stream Temperature: stream_temp
#     Output Summary: basin_sum, subbasin, map_results, prms_summary,
#                     nhru_summary, nsub_summary, water_balance
#                     basin_summary, nsegment_summary
#      Preprocessing: write_climate_hru, frost_date
# --------------------------------------------------------------------
#
#
# ==========================================================================
# Please give careful consideration to fixing all ERROR and WARNING messages
# ==========================================================================
#
#
#     Active modules listed in the order in which they are called
#
#         Process                   Module                Version Date
# ====================================================================
# GSFLOW Computation Order       gsflow_prms                2018-09-26
# Basin Definition               basin                      2018-04-06
# Cascading Flow                 cascade                    2018-05-25
# Common States and Fluxes       climateflow                2018-09-19
# Potential Solar Radiation      soltab                     2016-09-09
# PRMS Set Time Variables        prms_time                  2015-03-31
# Time Series Data               obs                        2018-02-23
# Temperature Distribution       temp_1sta                  2018-01-16
# Precipitation Distribution     precip_1sta                2016-10-21
# Solar Radiation Distribution   ddsolrad                   2016-11-03
# Transpiration Distribution     transp_tindex              2015-01-06
# Potential Evapotranspiration   potet_jh                   2016-05-10
# Canopy Interception            intcp                      2018-02-26
# Snow Dynamics                  snowcomp                   2018-05-04
# Surface Runoff                 srunoff_smidx              2018-04-25
# Soil Zone Computations         soilzone                   2018-09-19
# Groundwater                    gwflow                     2018-02-26
# Streamflow Routing             strmflow                   2014-12-02
# Summary                        basin_sum                  2017-10-21
# Output Summary                 map_results                2018-04-25
#  WARNING, map_results requested with nmapOutVars equal 0
#  no map_results output is produced
# Output Summary                 subbasin                   2018-04-25
# ====================================================================
#
# Writing PRMS Water Budget File: D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_model_output.out
#
# Simulation time period: 1982/08/01 - 1990/01/01
#
# ====================================================================
#
#
#
# WARNING: parameter_check_flag is duplicated in the control file D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_cont.control.
#
#
#
# WARNING: print_debug is duplicated in the control file D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_cont.control.
#
#
# WARNING: dimension 'nlake_hrus' is not required; file is D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_par_0.params; line number 38
#
# WARNING: parameter 'hru_tlaps' is not required; file is D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_par_0.params; line number 19579
#
# WARNING: parameter 'gvr_cell_id' is not required; file is D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_par_1.params; line number 24
#
# WARNING: parameter 'mapvars_freq' is not required; file is D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_par_2.params; line number 137
#
# WARNING: parameter 'mapvars_units' is not required; file is D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_par_2.params; line number 144
#
# WARNING: parameter 'prms_warmup' is not required; file is D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_par_2.params; line number 225
#
# WARNING: parameter 'lake_hru_id' is not required; file is D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_par_3.params; line number 71217
#
# WARNING: parameter snowpack_init is used by module snowcomp but values are not
#          set in the Parameter File. Module default values are being used.
# Loading the statvar output file .....
# Finished Load the statvar output file .....
#
# ****** Par =  gwflow_coef, Facc = 1.75 ******
# Writing the project files .....
#
# changing model workspace...
#    D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files
# Control file is written...
# Parameters files are written...
# Data file is written...
# Modflow files are written...
# pyGSFLOW is using the following executable to run the model: D:\Training\gsflowID2447_classrepo\bin\gsflow.exe
#
# (base) D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files>D:\Training\gsflowID2447_classrepo\bin\gsflow.exe D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_cont.control
#
#                Precipitation-Runoff Modeling System (PRMS)
#                        Version 5.0.0 06/01/2018
#
#         Process            Available Modules
# --------------------------------------------------------------------
#   Basin Definition: basin
#     Cascading Flow: cascade
#   Time Series Data: obs, water_use_read, dynamic_param_read
#    Potet Solar Rad: soltab
#   Temperature Dist: temp_1sta, temp_laps, temp_dist2, climate_hru
#        Precip Dist: precip_1sta, precip_laps, precip_dist2,
#                     climate_hru
# Temp & Precip Dist: xyz_dist, ide_dist
#     Solar Rad Dist: ccsolrad, ddsolrad, climate_hru
# Transpiration Dist: transp_tindex, climate_hru, transp_frost
#       Potential ET: potet_hamon, potet_jh, potet_pan, climate_hru,
#                     potet_hs, potet_pt, potet_pm, potet_pm_sta
#       Interception: intcp
#      Snow Dynamics: snowcomp
#     Surface Runoff: srunoff_smidx, srunoff_carea
#          Soil Zone: soilzone
#        Groundwater: gwflow
# Streamflow Routing: strmflow, strmflow_in_out, muskingum,
#                     muskingum_lake
# Stream Temperature: stream_temp
#     Output Summary: basin_sum, subbasin, map_results, prms_summary,
#                     nhru_summary, nsub_summary, water_balance
#                     basin_summary, nsegment_summary
#      Preprocessing: write_climate_hru, frost_date
# --------------------------------------------------------------------
#
#
# ==========================================================================
# Please give careful consideration to fixing all ERROR and WARNING messages
# ==========================================================================
#
#
#     Active modules listed in the order in which they are called
#
#         Process                   Module                Version Date
# ====================================================================
# GSFLOW Computation Order       gsflow_prms                2018-09-26
# Basin Definition               basin                      2018-04-06
# Cascading Flow                 cascade                    2018-05-25
# Common States and Fluxes       climateflow                2018-09-19
# Potential Solar Radiation      soltab                     2016-09-09
# PRMS Set Time Variables        prms_time                  2015-03-31
# Time Series Data               obs                        2018-02-23
# Temperature Distribution       temp_1sta                  2018-01-16
# Precipitation Distribution     precip_1sta                2016-10-21
# Solar Radiation Distribution   ddsolrad                   2016-11-03
# Transpiration Distribution     transp_tindex              2015-01-06
# Potential Evapotranspiration   potet_jh                   2016-05-10
# Canopy Interception            intcp                      2018-02-26
# Snow Dynamics                  snowcomp                   2018-05-04
# Surface Runoff                 srunoff_smidx              2018-04-25
# Soil Zone Computations         soilzone                   2018-09-19
# Groundwater                    gwflow                     2018-02-26
# Streamflow Routing             strmflow                   2014-12-02
# Summary                        basin_sum                  2017-10-21
# Output Summary                 map_results                2018-04-25
#  WARNING, map_results requested with nmapOutVars equal 0
#  no map_results output is produced
# Output Summary                 subbasin                   2018-04-25
# ====================================================================
#
# Writing PRMS Water Budget File: D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_model_output.out
#
# Simulation time period: 1982/08/01 - 1990/01/01
#
# ====================================================================
#
#
#
# WARNING: parameter_check_flag is duplicated in the control file D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_cont.control.
#
#
#
# WARNING: print_debug is duplicated in the control file D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_cont.control.
#
#
# WARNING: dimension 'nlake_hrus' is not required; file is D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_par_0.params; line number 38
#
# WARNING: parameter 'hru_tlaps' is not required; file is D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_par_0.params; line number 19579
#
# WARNING: parameter 'gvr_cell_id' is not required; file is D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_par_1.params; line number 24
#
# WARNING: parameter 'mapvars_freq' is not required; file is D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_par_2.params; line number 137
#
# WARNING: parameter 'mapvars_units' is not required; file is D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_par_2.params; line number 144
#
# WARNING: parameter 'prms_warmup' is not required; file is D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_par_2.params; line number 225
#
# WARNING: parameter 'lake_hru_id' is not required; file is D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_par_3.params; line number 71217
#
# WARNING: parameter snowpack_init is used by module snowcomp but values are not
#          set in the Parameter File. Module default values are being used.
# Loading the statvar output file .....
# Finished Load the statvar output file .....
#
# ****** Par =  gwflow_coef, Facc = 2.0 ******
# Writing the project files .....
#
# changing model workspace...
#    D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files
# Control file is written...
# Parameters files are written...
# Data file is written...
# Modflow files are written...
# pyGSFLOW is using the following executable to run the model: D:\Training\gsflowID2447_classrepo\bin\gsflow.exe
#
# (base) D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files>D:\Training\gsflowID2447_classrepo\bin\gsflow.exe D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_cont.control
#
#                Precipitation-Runoff Modeling System (PRMS)
#                        Version 5.0.0 06/01/2018
#
#         Process            Available Modules
# --------------------------------------------------------------------
#   Basin Definition: basin
#     Cascading Flow: cascade
#   Time Series Data: obs, water_use_read, dynamic_param_read
#    Potet Solar Rad: soltab
#   Temperature Dist: temp_1sta, temp_laps, temp_dist2, climate_hru
#        Precip Dist: precip_1sta, precip_laps, precip_dist2,
#                     climate_hru
# Temp & Precip Dist: xyz_dist, ide_dist
#     Solar Rad Dist: ccsolrad, ddsolrad, climate_hru
# Transpiration Dist: transp_tindex, climate_hru, transp_frost
#       Potential ET: potet_hamon, potet_jh, potet_pan, climate_hru,
#                     potet_hs, potet_pt, potet_pm, potet_pm_sta
#       Interception: intcp
#      Snow Dynamics: snowcomp
#     Surface Runoff: srunoff_smidx, srunoff_carea
#          Soil Zone: soilzone
#        Groundwater: gwflow
# Streamflow Routing: strmflow, strmflow_in_out, muskingum,
#                     muskingum_lake
# Stream Temperature: stream_temp
#     Output Summary: basin_sum, subbasin, map_results, prms_summary,
#                     nhru_summary, nsub_summary, water_balance
#                     basin_summary, nsegment_summary
#      Preprocessing: write_climate_hru, frost_date
# --------------------------------------------------------------------
#
#
# ==========================================================================
# Please give careful consideration to fixing all ERROR and WARNING messages
# ==========================================================================
#
#
#     Active modules listed in the order in which they are called
#
#         Process                   Module                Version Date
# ====================================================================
# GSFLOW Computation Order       gsflow_prms                2018-09-26
# Basin Definition               basin                      2018-04-06
# Cascading Flow                 cascade                    2018-05-25
# Common States and Fluxes       climateflow                2018-09-19
# Potential Solar Radiation      soltab                     2016-09-09
# PRMS Set Time Variables        prms_time                  2015-03-31
# Time Series Data               obs                        2018-02-23
# Temperature Distribution       temp_1sta                  2018-01-16
# Precipitation Distribution     precip_1sta                2016-10-21
# Solar Radiation Distribution   ddsolrad                   2016-11-03
# Transpiration Distribution     transp_tindex              2015-01-06
# Potential Evapotranspiration   potet_jh                   2016-05-10
# Canopy Interception            intcp                      2018-02-26
# Snow Dynamics                  snowcomp                   2018-05-04
# Surface Runoff                 srunoff_smidx              2018-04-25
# Soil Zone Computations         soilzone                   2018-09-19
# Groundwater                    gwflow                     2018-02-26
# Streamflow Routing             strmflow                   2014-12-02
# Summary                        basin_sum                  2017-10-21
# Output Summary                 map_results                2018-04-25
#  WARNING, map_results requested with nmapOutVars equal 0
#  no map_results output is produced
# Output Summary                 subbasin                   2018-04-25
# ====================================================================
#
# Writing PRMS Water Budget File: D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_model_output.out
#
# Simulation time period: 1982/08/01 - 1990/01/01
#
# ====================================================================
#
#
#
# WARNING: parameter_check_flag is duplicated in the control file D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_cont.control.
#
#
#
# WARNING: print_debug is duplicated in the control file D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_cont.control.
#
#
# WARNING: dimension 'nlake_hrus' is not required; file is D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_par_0.params; line number 38
#
# WARNING: parameter 'hru_tlaps' is not required; file is D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_par_0.params; line number 19579
#
# WARNING: parameter 'gvr_cell_id' is not required; file is D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_par_1.params; line number 24
#
# WARNING: parameter 'mapvars_freq' is not required; file is D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_par_2.params; line number 137
#
# WARNING: parameter 'mapvars_units' is not required; file is D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_par_2.params; line number 144
#
# WARNING: parameter 'prms_warmup' is not required; file is D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_par_2.params; line number 225
#
# WARNING: parameter 'lake_hru_id' is not required; file is D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_par_3.params; line number 71217
#
# WARNING: parameter snowpack_init is used by module snowcomp but values are not
#          set in the Parameter File. Module default values are being used.
# Loading the statvar output file .....
# Finished Load the statvar output file .....
#
# ****** Par =  gwflow_coef, Facc = 2.25 ******
# Writing the project files .....
#
# changing model workspace...
#    D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files
# Control file is written...
# Parameters files are written...
# Data file is written...
# Modflow files are written...
# pyGSFLOW is using the following executable to run the model: D:\Training\gsflowID2447_classrepo\bin\gsflow.exe
#
# (base) D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files>D:\Training\gsflowID2447_classrepo\bin\gsflow.exe D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_cont.control
#
#                Precipitation-Runoff Modeling System (PRMS)
#                        Version 5.0.0 06/01/2018
#
#         Process            Available Modules
# --------------------------------------------------------------------
#   Basin Definition: basin
#     Cascading Flow: cascade
#   Time Series Data: obs, water_use_read, dynamic_param_read
#    Potet Solar Rad: soltab
#   Temperature Dist: temp_1sta, temp_laps, temp_dist2, climate_hru
#        Precip Dist: precip_1sta, precip_laps, precip_dist2,
#                     climate_hru
# Temp & Precip Dist: xyz_dist, ide_dist
#     Solar Rad Dist: ccsolrad, ddsolrad, climate_hru
# Transpiration Dist: transp_tindex, climate_hru, transp_frost
#       Potential ET: potet_hamon, potet_jh, potet_pan, climate_hru,
#                     potet_hs, potet_pt, potet_pm, potet_pm_sta
#       Interception: intcp
#      Snow Dynamics: snowcomp
#     Surface Runoff: srunoff_smidx, srunoff_carea
#          Soil Zone: soilzone
#        Groundwater: gwflow
# Streamflow Routing: strmflow, strmflow_in_out, muskingum,
#                     muskingum_lake
# Stream Temperature: stream_temp
#     Output Summary: basin_sum, subbasin, map_results, prms_summary,
#                     nhru_summary, nsub_summary, water_balance
#                     basin_summary, nsegment_summary
#      Preprocessing: write_climate_hru, frost_date
# --------------------------------------------------------------------
#
#
# ==========================================================================
# Please give careful consideration to fixing all ERROR and WARNING messages
# ==========================================================================
#
#
#     Active modules listed in the order in which they are called
#
#         Process                   Module                Version Date
# ====================================================================
# GSFLOW Computation Order       gsflow_prms                2018-09-26
# Basin Definition               basin                      2018-04-06
# Cascading Flow                 cascade                    2018-05-25
# Common States and Fluxes       climateflow                2018-09-19
# Potential Solar Radiation      soltab                     2016-09-09
# PRMS Set Time Variables        prms_time                  2015-03-31
# Time Series Data               obs                        2018-02-23
# Temperature Distribution       temp_1sta                  2018-01-16
# Precipitation Distribution     precip_1sta                2016-10-21
# Solar Radiation Distribution   ddsolrad                   2016-11-03
# Transpiration Distribution     transp_tindex              2015-01-06
# Potential Evapotranspiration   potet_jh                   2016-05-10
# Canopy Interception            intcp                      2018-02-26
# Snow Dynamics                  snowcomp                   2018-05-04
# Surface Runoff                 srunoff_smidx              2018-04-25
# Soil Zone Computations         soilzone                   2018-09-19
# Groundwater                    gwflow                     2018-02-26
# Streamflow Routing             strmflow                   2014-12-02
# Summary                        basin_sum                  2017-10-21
# Output Summary                 map_results                2018-04-25
#  WARNING, map_results requested with nmapOutVars equal 0
#  no map_results output is produced
# Output Summary                 subbasin                   2018-04-25
# ====================================================================
#
# Writing PRMS Water Budget File: D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_model_output.out
#
# Simulation time period: 1982/08/01 - 1990/01/01
#
# ====================================================================
#
#
#
# WARNING: parameter_check_flag is duplicated in the control file D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_cont.control.
#
#
#
# WARNING: print_debug is duplicated in the control file D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_cont.control.
#
#
# WARNING: dimension 'nlake_hrus' is not required; file is D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_par_0.params; line number 38
#
# WARNING: parameter 'hru_tlaps' is not required; file is D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_par_0.params; line number 19579
#
# WARNING: parameter 'gvr_cell_id' is not required; file is D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_par_1.params; line number 24
#
# WARNING: parameter 'mapvars_freq' is not required; file is D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_par_2.params; line number 137
#
# WARNING: parameter 'mapvars_units' is not required; file is D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_par_2.params; line number 144
#
# WARNING: parameter 'prms_warmup' is not required; file is D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_par_2.params; line number 225
#
# WARNING: parameter 'lake_hru_id' is not required; file is D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_par_3.params; line number 71217
#
# WARNING: parameter snowpack_init is used by module snowcomp but values are not
#          set in the Parameter File. Module default values are being used.
# Loading the statvar output file .....
# Finished Load the statvar output file .....
#
# ****** Par =  snarea_curve, Facc = 0.75 ******
# Writing the project files .....
#
# changing model workspace...
#    D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files
# Control file is written...
# Parameters files are written...
# Data file is written...
# Modflow files are written...
# pyGSFLOW is using the following executable to run the model: D:\Training\gsflowID2447_classrepo\bin\gsflow.exe
#
# (base) D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files>D:\Training\gsflowID2447_classrepo\bin\gsflow.exe D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_cont.control
#
#                Precipitation-Runoff Modeling System (PRMS)
#                        Version 5.0.0 06/01/2018
#
#         Process            Available Modules
# --------------------------------------------------------------------
#   Basin Definition: basin
#     Cascading Flow: cascade
#   Time Series Data: obs, water_use_read, dynamic_param_read
#    Potet Solar Rad: soltab
#   Temperature Dist: temp_1sta, temp_laps, temp_dist2, climate_hru
#        Precip Dist: precip_1sta, precip_laps, precip_dist2,
#                     climate_hru
# Temp & Precip Dist: xyz_dist, ide_dist
#     Solar Rad Dist: ccsolrad, ddsolrad, climate_hru
# Transpiration Dist: transp_tindex, climate_hru, transp_frost
#       Potential ET: potet_hamon, potet_jh, potet_pan, climate_hru,
#                     potet_hs, potet_pt, potet_pm, potet_pm_sta
#       Interception: intcp
#      Snow Dynamics: snowcomp
#     Surface Runoff: srunoff_smidx, srunoff_carea
#          Soil Zone: soilzone
#        Groundwater: gwflow
# Streamflow Routing: strmflow, strmflow_in_out, muskingum,
#                     muskingum_lake
# Stream Temperature: stream_temp
#     Output Summary: basin_sum, subbasin, map_results, prms_summary,
#                     nhru_summary, nsub_summary, water_balance
#                     basin_summary, nsegment_summary
#      Preprocessing: write_climate_hru, frost_date
# --------------------------------------------------------------------
#
#
# ==========================================================================
# Please give careful consideration to fixing all ERROR and WARNING messages
# ==========================================================================
#
#
#     Active modules listed in the order in which they are called
#
#         Process                   Module                Version Date
# ====================================================================
# GSFLOW Computation Order       gsflow_prms                2018-09-26
# Basin Definition               basin                      2018-04-06
# Cascading Flow                 cascade                    2018-05-25
# Common States and Fluxes       climateflow                2018-09-19
# Potential Solar Radiation      soltab                     2016-09-09
# PRMS Set Time Variables        prms_time                  2015-03-31
# Time Series Data               obs                        2018-02-23
# Temperature Distribution       temp_1sta                  2018-01-16
# Precipitation Distribution     precip_1sta                2016-10-21
# Solar Radiation Distribution   ddsolrad                   2016-11-03
# Transpiration Distribution     transp_tindex              2015-01-06
# Potential Evapotranspiration   potet_jh                   2016-05-10
# Canopy Interception            intcp                      2018-02-26
# Snow Dynamics                  snowcomp                   2018-05-04
# Surface Runoff                 srunoff_smidx              2018-04-25
# Soil Zone Computations         soilzone                   2018-09-19
# Groundwater                    gwflow                     2018-02-26
# Streamflow Routing             strmflow                   2014-12-02
# Summary                        basin_sum                  2017-10-21
# Output Summary                 map_results                2018-04-25
#  WARNING, map_results requested with nmapOutVars equal 0
#  no map_results output is produced
# Output Summary                 subbasin                   2018-04-25
# ====================================================================
# Writing PRMS Water Budget File: D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_model_output.out
#
# Simulation time period: 1982/08/01 - 1990/01/01
#
# ====================================================================
#
#
#
# WARNING: parameter_check_flag is duplicated in the control file D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_cont.control.
#
#
#
# WARNING: print_debug is duplicated in the control file D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_cont.control.
#
#
# WARNING: dimension 'nlake_hrus' is not required; file is D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_par_0.params; line number 38
#
# WARNING: parameter 'hru_tlaps' is not required; file is D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_par_0.params; line number 19579
#
# WARNING: parameter 'gvr_cell_id' is not required; file is D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_par_1.params; line number 24
#
# WARNING: parameter 'mapvars_freq' is not required; file is D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_par_2.params; line number 137
#
# ...
#
#         Process                   Module                Version Date
# ====================================================================
# GSFLOW Computation Order       gsflow_prms                2018-09-26
# Basin Definition               basin                      2018-04-06
# Cascading Flow                 cascade                    2018-05-25
# Common States and Fluxes       climateflow                2018-09-19
# Potential Solar Radiation      soltab                     2016-09-09
# PRMS Set Time Variables        prms_time                  2015-03-31
# Time Series Data               obs                        2018-02-23
# Temperature Distribution       temp_1sta                  2018-01-16
# Precipitation Distribution     precip_1sta                2016-10-21
# Solar Radiation Distribution   ddsolrad                   2016-11-03
# Transpiration Distribution     transp_tindex              2015-01-06
# Potential Evapotranspiration   potet_jh                   2016-05-10
# Canopy Interception            intcp                      2018-02-26
# Snow Dynamics                  snowcomp                   2018-05-04
# Surface Runoff                 srunoff_smidx              2018-04-25
# Soil Zone Computations         soilzone                   2018-09-19
# Groundwater                    gwflow                     2018-02-26
# Streamflow Routing             strmflow                   2014-12-02
# Summary                        basin_sum                  2017-10-21
# Output Summary                 map_results                2018-04-25
#  WARNING, map_results requested with nmapOutVars equal 0
#  no map_results output is produced
# Output Summary                 subbasin                   2018-04-25
# ====================================================================
#
# Writing PRMS Water Budget File: D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_model_output.out
#
# Simulation time period: 1982/08/01 - 1990/01/01
#
# ====================================================================
#
#
#
# WARNING: parameter_check_flag is duplicated in the control file D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_cont.control.
#
#
#
# WARNING: print_debug is duplicated in the control file D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_cont.control.
#
#
# WARNING: dimension 'nlake_hrus' is not required; file is D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_par_0.params; line number 38
#
# WARNING: parameter 'hru_tlaps' is not required; file is D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_par_0.params; line number 19579
#
# WARNING: parameter 'gvr_cell_id' is not required; file is D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_par_1.params; line number 24
#
# WARNING: parameter 'mapvars_freq' is not required; file is D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_par_2.params; line number 137
#
# WARNING: parameter 'mapvars_units' is not required; file is D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_par_2.params; line number 144
#
# WARNING: parameter 'prms_warmup' is not required; file is D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_par_2.params; line number 225
#
# WARNING: parameter 'lake_hru_id' is not required; file is D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_par_3.params; line number 71217
#
# WARNING: parameter snowpack_init is used by module snowcomp but values are not
#          set in the Parameter File. Module default values are being used.
# Loading the statvar output file .....
# Finished Load the statvar output file .....
#
# ****** Par =  ssr2gw_rate, Facc = 2.0 ******
# Writing the project files .....
#
# changing model workspace...
#    D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files
# Control file is written...
# Parameters files are written...
# Data file is written...
# Modflow files are written...
# pyGSFLOW is using the following executable to run the model: D:\Training\gsflowID2447_classrepo\bin\gsflow.exe
#
# (base) D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files>D:\Training\gsflowID2447_classrepo\bin\gsflow.exe D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_cont.control
#
#                Precipitation-Runoff Modeling System (PRMS)
#                        Version 5.0.0 06/01/2018
#
#         Process            Available Modules
# --------------------------------------------------------------------
#   Basin Definition: basin
#     Cascading Flow: cascade
#   Time Series Data: obs, water_use_read, dynamic_param_read
#    Potet Solar Rad: soltab
#   Temperature Dist: temp_1sta, temp_laps, temp_dist2, climate_hru
#        Precip Dist: precip_1sta, precip_laps, precip_dist2,
#                     climate_hru
# Temp & Precip Dist: xyz_dist, ide_dist
#     Solar Rad Dist: ccsolrad, ddsolrad, climate_hru
# Transpiration Dist: transp_tindex, climate_hru, transp_frost
#       Potential ET: potet_hamon, potet_jh, potet_pan, climate_hru,
#                     potet_hs, potet_pt, potet_pm, potet_pm_sta
#       Interception: intcp
#      Snow Dynamics: snowcomp
#     Surface Runoff: srunoff_smidx, srunoff_carea
#          Soil Zone: soilzone
#        Groundwater: gwflow
# Streamflow Routing: strmflow, strmflow_in_out, muskingum,
#                     muskingum_lake
# Stream Temperature: stream_temp
#     Output Summary: basin_sum, subbasin, map_results, prms_summary,
#                     nhru_summary, nsub_summary, water_balance
#                     basin_summary, nsegment_summary
#      Preprocessing: write_climate_hru, frost_date
# --------------------------------------------------------------------
#
#
# ==========================================================================
# Please give careful consideration to fixing all ERROR and WARNING messages
# ==========================================================================
#
#
#     Active modules listed in the order in which they are called
#
#         Process                   Module                Version Date
# ====================================================================
# GSFLOW Computation Order       gsflow_prms                2018-09-26
# Basin Definition               basin                      2018-04-06
# Cascading Flow                 cascade                    2018-05-25
# Common States and Fluxes       climateflow                2018-09-19
# Potential Solar Radiation      soltab                     2016-09-09
# PRMS Set Time Variables        prms_time                  2015-03-31
# Time Series Data               obs                        2018-02-23
# Temperature Distribution       temp_1sta                  2018-01-16
# Precipitation Distribution     precip_1sta                2016-10-21
# Solar Radiation Distribution   ddsolrad                   2016-11-03
# Transpiration Distribution     transp_tindex              2015-01-06
# Potential Evapotranspiration   potet_jh                   2016-05-10
# Canopy Interception            intcp                      2018-02-26
# Snow Dynamics                  snowcomp                   2018-05-04
# Surface Runoff                 srunoff_smidx              2018-04-25
# Soil Zone Computations         soilzone                   2018-09-19
# Groundwater                    gwflow                     2018-02-26
# Streamflow Routing             strmflow                   2014-12-02
# Summary                        basin_sum                  2017-10-21
# Output Summary                 map_results                2018-04-25
#  WARNING, map_results requested with nmapOutVars equal 0
#  no map_results output is produced
# Output Summary                 subbasin                   2018-04-25
# ====================================================================
# Writing PRMS Water Budget File: D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_model_output.out
#
# Simulation time period: 1982/08/01 - 1990/01/01
#
# ====================================================================
#
#
#
# WARNING: parameter_check_flag is duplicated in the control file D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_cont.control.
#
#
#
# WARNING: print_debug is duplicated in the control file D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_cont.control.
#
#
# WARNING: dimension 'nlake_hrus' is not required; file is D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_par_0.params; line number 38
#
# WARNING: parameter 'hru_tlaps' is not required; file is D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_par_0.params; line number 19579
#
# WARNING: parameter 'gvr_cell_id' is not required; file is D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_par_1.params; line number 24
#
# WARNING: parameter 'mapvars_freq' is not required; file is D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_par_2.params; line number 137
#
# WARNING: parameter 'mapvars_units' is not required; file is D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_par_2.params; line number 144
#
# WARNING: parameter 'prms_warmup' is not required; file is D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_par_2.params; line number 225
#
# WARNING: parameter 'lake_hru_id' is not required; file is D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_par_3.params; line number 71217
#
# WARNING: parameter snowpack_init is used by module snowcomp but values are not
#          set in the Parameter File. Module default values are being used.
# Loading the statvar output file .....
# Finished Load the statvar output file .....
#
# ****** Par =  ssr2gw_rate, Facc = 2.25 ******
# Writing the project files .....
#
# changing model workspace...
#    D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files
# Control file is written...
# Parameters files are written...
# Data file is written...
# Modflow files are written...
# pyGSFLOW is using the following executable to run the model: D:\Training\gsflowID2447_classrepo\bin\gsflow.exe
#
# (base) D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files>D:\Training\gsflowID2447_classrepo\bin\gsflow.exe D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_cont.control
#
#                Precipitation-Runoff Modeling System (PRMS)
#                        Version 5.0.0 06/01/2018
#
#         Process            Available Modules
# --------------------------------------------------------------------
#   Basin Definition: basin
#     Cascading Flow: cascade
#   Time Series Data: obs, water_use_read, dynamic_param_read
#    Potet Solar Rad: soltab
#   Temperature Dist: temp_1sta, temp_laps, temp_dist2, climate_hru
#        Precip Dist: precip_1sta, precip_laps, precip_dist2,
#                     climate_hru
# Temp & Precip Dist: xyz_dist, ide_dist
#     Solar Rad Dist: ccsolrad, ddsolrad, climate_hru
# Transpiration Dist: transp_tindex, climate_hru, transp_frost
#       Potential ET: potet_hamon, potet_jh, potet_pan, climate_hru,
#                     potet_hs, potet_pt, potet_pm, potet_pm_sta
#       Interception: intcp
#      Snow Dynamics: snowcomp
#     Surface Runoff: srunoff_smidx, srunoff_carea
#          Soil Zone: soilzone
#        Groundwater: gwflow
# Streamflow Routing: strmflow, strmflow_in_out, muskingum,
#                     muskingum_lake
# Stream Temperature: stream_temp
#     Output Summary: basin_sum, subbasin, map_results, prms_summary,
#                     nhru_summary, nsub_summary, water_balance
#                     basin_summary, nsegment_summary
#      Preprocessing: write_climate_hru, frost_date
# --------------------------------------------------------------------
#
#
# ==========================================================================
# Please give careful consideration to fixing all ERROR and WARNING messages
# ==========================================================================
#
#
#     Active modules listed in the order in which they are called
#
#         Process                   Module                Version Date
# ====================================================================
# GSFLOW Computation Order       gsflow_prms                2018-09-26
# Basin Definition               basin                      2018-04-06
# Cascading Flow                 cascade                    2018-05-25
# Common States and Fluxes       climateflow                2018-09-19
# Potential Solar Radiation      soltab                     2016-09-09
# PRMS Set Time Variables        prms_time                  2015-03-31
# Time Series Data               obs                        2018-02-23
# Temperature Distribution       temp_1sta                  2018-01-16
# Precipitation Distribution     precip_1sta                2016-10-21
# Solar Radiation Distribution   ddsolrad                   2016-11-03
# Transpiration Distribution     transp_tindex              2015-01-06
# Potential Evapotranspiration   potet_jh                   2016-05-10
# Canopy Interception            intcp                      2018-02-26
# Snow Dynamics                  snowcomp                   2018-05-04
# Surface Runoff                 srunoff_smidx              2018-04-25
# Soil Zone Computations         soilzone                   2018-09-19
# Groundwater                    gwflow                     2018-02-26
# Streamflow Routing             strmflow                   2014-12-02
# Summary                        basin_sum                  2017-10-21
# Output Summary                 map_results                2018-04-25
#  WARNING, map_results requested with nmapOutVars equal 0
#  no map_results output is produced
# Output Summary                 subbasin                   2018-04-25
# ====================================================================
#
# Writing PRMS Water Budget File: D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_model_output.out
#
# Simulation time period: 1982/08/01 - 1990/01/01
#
# ====================================================================
#
#
#
# WARNING: parameter_check_flag is duplicated in the control file D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_cont.control.
#
#
#
# WARNING: print_debug is duplicated in the control file D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_cont.control.
#
#
# WARNING: dimension 'nlake_hrus' is not required; file is D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_par_0.params; line number 38
#
# WARNING: parameter 'hru_tlaps' is not required; file is D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_par_0.params; line number 19579
#
# WARNING: parameter 'gvr_cell_id' is not required; file is D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_par_1.params; line number 24
#
# WARNING: parameter 'mapvars_freq' is not required; file is D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_par_2.params; line number 137
#
# WARNING: parameter 'mapvars_units' is not required; file is D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_par_2.params; line number 144
#
# WARNING: parameter 'prms_warmup' is not required; file is D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_par_2.params; line number 225
#
# WARNING: parameter 'lake_hru_id' is not required; file is D:\Training\gsflowID2447_classrepo\exercises\saghen_pyGSFLOW\prms_files\saghen_new_par_3.params; line number 71217
#
# WARNING: parameter snowpack_init is used by module snowcomp but values are not
#          set in the Parameter File. Module default values are being used.
# Loading the statvar output file .....
# Finished Load the statvar output file .....
# Wall time: 3min 5s

# %%
plt.figure(figsize=(15,5))
i = 1
for par in all_errors.keys():
    plt.subplot(1,3,i)
    plt.plot(factors, all_errors[par], label = par, marker='s' )
    plt.ylabel("Mean Squared Error (cft)")
    i = i + 1
    plt.title(par)

# %% [markdown]
# ### Remember: This calibration method is usefull only if input parameters are independent. In PEST, the parameter are changed concurrently.
