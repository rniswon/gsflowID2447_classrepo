# %% [markdown]
#  <img src=".\figures\motto2.png">
#
#  https://github.com/aymanalz/pygsflow
#
# # Introduction to PyGSFLOW
#
# Simulating integrated hydrological systems requires working with a large set of input parameters and output variables that are saved in several files. Thus, changing input parameters and reading output can be laborious task. This is particularly true in  model calibration and sensitivity and uncertainty analysis. PyGSFLOW allows modeler to focus on the hydrologic aspect of the problem as it simplifies most of modeling operations such as modifying model input files, running the model, and reading and processing the model. PyGSFLOW uses Flopy to work with MODFLOW files.   In this exercise  we will illustrate the basic elements of PyGSFLOW; and in the next exercise we will demonstrate how it can be used to achieve fairly complex tasks using small number of commands.

# %%
from gsflow import Gsflow  # Make sure that Gsflow class is imported. 
import os, sys
import matplotlib.pyplot as plt
# Out:
# flopy is installed in D:\Workspace\classes\gsflowID2447_classrepo\python_packages\flopy\flopy

# %% [markdown]
# ## pyGSFLOW in a nutshell
# pyGSFLOW consists of three main components (See Figures below). These components are: (1) Control class, (2) a PRMS class, and (3) Flopy package.The Control class handles operations and information related the control file. The PRMS objects consists of a number of other classes such as :
#
#     (1) the Parameters Class that handles all GSFLOW parameters that can be saved in one (or more) files,
#     (2) the Data class that handles Climate Data information.
#     (3) The output class that handles some of GSFLOW output.
#
#  The well know Flopy package (under mf class in pyGSFLOW) is used to handle data and operations related to MODFLOW.
#  <img src=".\figures\pyGSFLOW_processes.png">
#
#  ### Accessing Data in pyGSFLOW -- The Big Picture
#  To access any piece information within the GSFLOW model we will be using class names to navigates subclasses starting from the main class Gsflow. The following figure illustrates how this can be accomplished
#
#   <img src=".\figures\pyGSFLOW_processes2.png">

# %% [markdown]
# <img src=".\figures\warning.png"> WARNING: PyGSLFOW is a new package that is still under development. Some of the features that are not supported includes:
# (1) Reading and processing animation files and PRMS budget files,
# (2) Tools to check for errors in input files.
#
# https://github.com/aymanalz/pygsflow

# %% [markdown]
# ## Exercise
# ### (1) Loading an existing GSFLOW project
# Let us start by loading an existing GSFLOW project. To do so we need to pass the control file to the Gsflow
#  class that will upload information from model input files.

# %%
control_file = r"../models_data/prms/windows/sagehen.control"
gs = Gsflow(control_file = control_file)
# Out:
# PyGSFLOW ------ V0.0
# Control file is loaded
# Working on loading PRMS model ...
# Parameters will be read from a file/ files...
# Work on loadind the parameter files .....
# Prms model is loaded .....
# There are no Modflow files, PRMS model only

# %% [markdown]
# ### (2) Access data in GSFLOW inputs
# The "gs" variable in the previous cell is a name for the object that holds information about the two components of GSFLOW : PRMS and MODFLOW.
#
# ### (2.a) Control Class
# To access control information you can do something like
#
# gs.control.SOMEFUNCTION()
#
# For example, to get a list of records in a control file ...

# %%
gs.control.get_record_names()
# Out:
# ['mapOutVar_names',
#  'nmapOutVars',
#  'mapOutON_OFF',
#  'parameter_check_flag',
#  'prms_warmup',
#  'aniOutON_OFF',
#  'print_debug',
#  'aniOutVar_names',
#  'ani_output_file',
#  'csv_output_file',
#  'model_output_file',
#  'data_file',
#  'dispGraphsBuffSize',
#  'dispVar_element',
#  'dispVar_names',
#  'dispVar_plot',
#  'end_time',
#  'et_module',
#  'executable_desc',
#  'executable_model',
#  'gsflow_output_file',
#  'init_vars_from_file',
#  'initial_deltat',
#  'mms_user_dir',
#  'mms_user_out_dir',
#  'model_mode',
#  'modflow_name',
#  'naniOutVars',
#  'ndispGraphs',
#  'param_file',
#  'precip_module',
#  'param_print_file',
#  'save_vars_to_file',
#  'solrad_module',
#  'srunoff_module',
#  'start_time',
#  'nstatVars',
#  'statVar_element',
#  'statVar_names',
#  'stat_var_file',
#  'statsON_OFF',
#  'cascade_flag',
#  'cascadegw_flag',
#  'temp_module',
#  'var_save_file',
#  'stats_output_file',
#  'var_init_file',
#  'rpt_days',
#  'capillary_module',
#  'parameter_check_flag',
#  'print_debug']

# %%
# Assuming that we are interested in looking closer into ET Module 
et_module = gs.control.get_record('et_module')

# %%
# Notice that the result is an object for the et_module...
print(et_module) # printing the object will generate a standard PRMS template for the record as it appears in 
                 # the control file.
# Out:
# ####
# et_module
# 1
# 4
# potet_jh
# ####

# %% [markdown]
# <img style="float: left;" src = "./figures/Qs.PNG" width="20">
# ### Can you get the starting date from the control object?

# %%
start_date = gs.control.get_record('start_time')
print(start_date) # Notice that when the number of values in the record is large, pyGSFLOW echos
                                           # the first four value to make the print compact.
# Out:
# ####
# start_time
# 6
# 1
# 1982
# 8
# 1
# 0.
# .
# .
# ####

# %%
## explore data in the control_record object
start_date.values
# Out:
# array([1982,    8,    1,    0,    0,    0])

# %%
# Values in any record can be accessed use .get_values() function
gs.control.get_values("start_time")
# Out:
# array([1982,    8,    1,    0,    0,    0])

# %%
# We can also change the value of a control record as follows
gs.control.set_values(name='start_time', values=[1990,1,1,0,0,0])
gs.control.get_values("start_time")
# Out:
# array([1990,    1,    1,    0,    0,    0])

# %%
# what about adding a new record to the control file?
gs.control.add_record(name = "xyz", values = [1, 2]) # Notice that we do not check whether the new record is valid or not.
print(gs.control.get_record('xyz'))
# Out:
# Warning: data type will be infered from data supplied
#
# ####
# xyz
# 2
# 1
# 1
# 2
# ####

# %%
# Let us see its location in the control file...
gs.control.get_record_names()
#Test adding the record any place you like
# Out:
# ['mapOutVar_names',
#  'nmapOutVars',
#  'mapOutON_OFF',
#  'parameter_check_flag',
#  'prms_warmup',
#  'aniOutON_OFF',
#  'print_debug',
#  'aniOutVar_names',
#  'ani_output_file',
#  'csv_output_file',
#  'model_output_file',
#  'data_file',
#  'dispGraphsBuffSize',
#  'dispVar_element',
#  'dispVar_names',
#  'dispVar_plot',
#  'end_time',
#  'et_module',
#  'executable_desc',
#  'executable_model',
#  'gsflow_output_file',
#  'init_vars_from_file',
#  'initial_deltat',
#  'mms_user_dir',
#  'mms_user_out_dir',
#  'model_mode',
#  'modflow_name',
#  'naniOutVars',
#  'ndispGraphs',
#  'param_file',
#  'precip_module',
#  'param_print_file',
#  'save_vars_to_file',
#  'solrad_module',
#  'srunoff_module',
#  'start_time',
#  'nstatVars',
#  'statVar_element',
#  'statVar_names',
#  'stat_var_file',
#  'statsON_OFF',
#  'cascade_flag',
#  'cascadegw_flag',
#  'temp_module',
#  'var_save_file',
#  'stats_output_file',
#  'var_init_file',
#  'rpt_days',
#  'capillary_module',
#  'parameter_check_flag',
#  'print_debug',
#  'xyz']

# %%
# Can you insert the new record in a certan location?
gs.control.add_record(name="hummingbird_2", values=['a', 'b'], after='save_vars_to_file')
gs.control.get_record_names()
# Out:
# Warning: data type will be infered from data supplied
# ['mapOutVar_names',
#  'nmapOutVars',
#  'mapOutON_OFF',
#  'parameter_check_flag',
#  'prms_warmup',
#  'aniOutON_OFF',
#  'print_debug',
#  'aniOutVar_names',
#  'ani_output_file',
#  'csv_output_file',
#  'model_output_file',
#  'data_file',
#  'dispGraphsBuffSize',
#  'dispVar_element',
#  'dispVar_names',
#  'dispVar_plot',
#  'end_time',
#  'et_module',
#  'executable_desc',
#  'executable_model',
#  'gsflow_output_file',
#  'init_vars_from_file',
#  'initial_deltat',
#  'mms_user_dir',
#  'mms_user_out_dir',
#  'model_mode',
#  'modflow_name',
#  'naniOutVars',
#  'ndispGraphs',
#  'param_file',
#  'precip_module',
#  'param_print_file',
#  'save_vars_to_file',
#  'hummingbird_2',
#  'solrad_module',
#  'srunoff_module',
#  'start_time',
#  'nstatVars',
#  'statVar_element',
#  'statVar_names',
#  'stat_var_file',
#  'statsON_OFF',
#  'cascade_flag',
#  'cascadegw_flag',
#  'temp_module',
#  'var_save_file',
#  'stats_output_file',
#  'var_init_file',
#  'rpt_days',
#  'capillary_module',
#  'parameter_check_flag',
#  'print_debug',
#  'xyz']

# %%
## If you add a new record without specifying the datatype, pyGSFLOW can 
##  guess the data type. A good a practise is to force data type as follows

# %%
# Similiar to adding, we can remove the record .
gs.control.remove_record("xyz") 
gs.control.remove_record("hummingbird_2") 
gs.control.get_record("hummingbird_2") # check if the wrong record is removed...
# Out:
# The record does not exist...

# %% [markdown]
# ### (2.b) Parameters information

# %%
gs.prms.parameters.get_record_names()
# Out:
# ['ncascade',
#  'ncascdgw',
#  'ndays',
#  'ndepl',
#  'ndeplval',
#  'nevap',
#  'ngw',
#  'ngwcell',
#  'nhru',
#  'nhrucell',
#  'nlake',
#  'nlake_hrus',
#  'nmonths',
#  'nobs',
#  'nrain',
#  'nreach',
#  'nsegment',
#  'nsnow',
#  'nsol',
#  'nssr',
#  'nsub',
#  'ntemp',
#  'one',
#  'adjmix_rain',
#  'basin_tsta',
#  'carea_max',
#  'dday_intcp',
#  'dday_slope',
#  'fastcoef_lin',
#  'fastcoef_sq',
#  'gwflow_coef',
#  'hru_percent_imperv',
#  'hru_subbasin',
#  'hru_tlaps',
#  'hru_tsta',
#  'jh_coef',
#  'pref_flow_den',
#  'rain_adj',
#  'sat_threshold',
#  'slowcoef_lin',
#  'slowcoef_sq',
#  'smidx_coef',
#  'snow_adj',
#  'soil_moist_max',
#  'soil_rechr_max',
#  'ssr2gw_rate',
#  'subbasin_down',
#  'tmax_allrain',
#  'tmax_allsnow',
#  'tmax_lapse',
#  'tmin_lapse',
#  'tsta_elev',
#  'cascade_flg',
#  'cascade_tol',
#  'circle_switch',
#  'gvr_cell_id',
#  'gw_down_id',
#  'gw_pct_up',
#  'gw_strmseg_down_id',
#  'gw_up_id',
#  'hru_down_id',
#  'hru_pct_up',
#  'hru_strmseg_down_id',
#  'hru_up_id',
#  'albset_rna',
#  'albset_rnm',
#  'albset_sna',
#  'albset_snm',
#  'cecn_coef',
#  'den_init',
#  'den_max',
#  'elev_units',
#  'emis_noppt',
#  'epan_coef',
#  'freeh2o_cap',
#  'gwsink_coef',
#  'gwstor_init',
#  'gwstor_min',
#  'hru_deplcrv',
#  'imperv_stor_max',
#  'mapvars_freq',
#  'mapvars_units',
#  'max_missing',
#  'melt_force',
#  'melt_look',
#  'outlet_sta',
#  'potet_sublim',
#  'ppt_rad_adj',
#  'precip_units',
#  'print_freq',
#  'print_type',
#  'prms_warmup',
#  'radadj_intcp',
#  'radadj_slope',
#  'radj_sppt',
#  'radj_wppt',
#  'radmax',
#  'runoff_units',
#  'settle_const',
#  'smidx_exp',
#  'snarea_curve',
#  'snarea_thresh',
#  'snowinfil_max',
#  'soil2gw_max',
#  'ssr2gw_exp',
#  'ssstor_init',
#  'temp_units',
#  'transp_beg',
#  'transp_end',
#  'transp_tmax',
#  'tstorm_mo',
#  'cov_type',
#  'covden_sum',
#  'covden_win',
#  'hru_area',
#  'hru_aspect',
#  'hru_elev',
#  'hru_lat',
#  'hru_psta',
#  'hru_slope',
#  'hru_type',
#  'jh_coef_hru',
#  'lake_hru_id',
#  'rad_trncf',
#  'snow_intcp',
#  'soil_moist_init',
#  'soil_rechr_init',
#  'soil_type',
#  'srain_intcp',
#  'tmax_adj',
#  'tmax_index',
#  'tmin_adj',
#  'wrain_intcp']

# %%
# how many parameters are there?
print(len(gs.prms.parameters.get_record_names()))

# Can you get the temperture station for each hru?
gs.prms.parameters.get_values('hru_tsta')
# Out:
# 133
# array([1, 1, 1, ..., 1, 1, 1])

# %%
# Can you change the parameters?

# %%
# What can we do else? Explore "Parameters" class?
dir(gs.prms.parameters)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__doc__',
#  '__format__',
#  '__getattribute__',
#  '__hash__',
#  '__init__',
#  '__module__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_parameter_files',
#  '_record_names',
#  'add_record',
#  'from_file',
#  'get_record',
#  'get_record_names',
#  'get_values',
#  'headers',
#  'parameter_files',
#  'parameters_list',
#  'remove_record',
#  'set_values',
#  'write']

# %% [markdown]
# ### (2.c) Data Class (Climate Data)

# %%
gs.prms.Data.data_df.head(10)
# Out:
#    Year  Month  Day  Hour  Minute  Second  tmax_0  tmin_0  precip_0  runoff_0  \
# 0  1953     10    1     0       0       0    -999    -999       0.0       2.9
# 1  1953     10    2     0       0       0    -999    -999       0.0       2.9
# 2  1953     10    3     0       0       0    -999    -999       0.0       2.9
# 3  1953     10    4     0       0       0    -999    -999       0.0       2.9
# 4  1953     10    5     0       0       0    -999    -999       0.0       2.9
# 5  1953     10    6     0       0       0    -999    -999       0.0       2.9
# 6  1953     10    7     0       0       0    -999    -999       0.0       2.9
# 7  1953     10    8     0       0       0    -999    -999       0.0       2.8
# 8  1953     10    9     0       0       0    -999    -999       0.0       2.9
# 9  1953     10   10     0       0       0    -999    -999       0.0       3.0
#
#         Date
# 0 1953-10-01
# 1 1953-10-02
# 2 1953-10-03
# 3 1953-10-04
# 4 1953-10-05
# 5 1953-10-06
# 6 1953-10-07
# 7 1953-10-08
# 8 1953-10-09
# 9 1953-10-10

# %%
climate_data = gs.prms.Data.data_df
plt.plot(climate_data['Date'], climate_data['tmax_0'])
# Out:
# D:\anaconda\envs\gsflow\lib\site-packages\pandas\plotting\_converter.py:129: FutureWarning: Using an implicitly registered datetime converter for a matplotlib plotting method. The converter was registered by pandas on import. Future versions of pandas will require you to explicitly register matplotlib converters.
#
# To register the converters:
# 	>>> from pandas.plotting import register_matplotlib_converters
# 	>>> register_matplotlib_converters()
#   warnings.warn(msg, FutureWarning)

# %%
df_to_plot = climate_data[climate_data['tmax_0']>-100]
plt.plot(df_to_plot['Date'], df_to_plot['tmax_0'])

# %%
## add a station
climate_data['precip_2'] = 10

# %%
climate_data.head(10)
# Out:
#    Year  Month  Day  Hour  Minute  Second  tmax_0  tmin_0  precip_0  runoff_0  \
# 0  1953     10    1     0       0       0    -999    -999       0.0       2.9
# 1  1953     10    2     0       0       0    -999    -999       0.0       2.9
# 2  1953     10    3     0       0       0    -999    -999       0.0       2.9
# 3  1953     10    4     0       0       0    -999    -999       0.0       2.9
# 4  1953     10    5     0       0       0    -999    -999       0.0       2.9
# 5  1953     10    6     0       0       0    -999    -999       0.0       2.9
# 6  1953     10    7     0       0       0    -999    -999       0.0       2.9
# 7  1953     10    8     0       0       0    -999    -999       0.0       2.8
# 8  1953     10    9     0       0       0    -999    -999       0.0       2.9
# 9  1953     10   10     0       0       0    -999    -999       0.0       3.0
#
#         Date  precip_2
# 0 1953-10-01        10
# 1 1953-10-02        10
# 2 1953-10-03        10
# 3 1953-10-04        10
# 4 1953-10-05        10
# 5 1953-10-06        10
# 6 1953-10-07        10
# 7 1953-10-08        10
# 8 1953-10-09        10
# 9 1953-10-10        10

# %%
#climate_data = climate_data.drop("precip_2", axis=1)
gs.prms.Data.data_df.drop("precip_2", axis=1, inplace=True)
gs.prms.Data.data_df
# Out:
#        Year  Month  Day  Hour  Minute  Second  tmax_0  tmin_0  precip_0  \
# 0      1953     10    1     0       0       0    -999    -999     0.000
# 1      1953     10    2     0       0       0    -999    -999     0.000
# 2      1953     10    3     0       0       0    -999    -999     0.000
# 3      1953     10    4     0       0       0    -999    -999     0.000
# 4      1953     10    5     0       0       0    -999    -999     0.000
# 5      1953     10    6     0       0       0    -999    -999     0.000
# 6      1953     10    7     0       0       0    -999    -999     0.000
# 7      1953     10    8     0       0       0    -999    -999     0.000
# 8      1953     10    9     0       0       0    -999    -999     0.000
# 9      1953     10   10     0       0       0    -999    -999     0.000
# 10     1953     10   11     0       0       0    -999    -999     5.842
# 11     1953     10   12     0       0       0    -999    -999     0.000
# 12     1953     10   13     0       0       0    -999    -999     0.000
# 13     1953     10   14     0       0       0    -999    -999     0.000
# 14     1953     10   15     0       0       0    -999    -999     0.000
# 15     1953     10   16     0       0       0    -999    -999     0.000
# 16     1953     10   17     0       0       0    -999    -999     0.000
# 17     1953     10   18     0       0       0    -999    -999     4.572
# 18     1953     10   19     0       0       0    -999    -999    17.018
# 19     1953     10   20     0       0       0    -999    -999     0.000
# 20     1953     10   21     0       0       0    -999    -999     0.000
# 21     1953     10   22     0       0       0    -999    -999     0.000
# 22     1953     10   23     0       0       0    -999    -999     0.000
# 23     1953     10   24     0       0       0    -999    -999     0.000
# 24     1953     10   25     0       0       0    -999    -999     0.000
# 25     1953     10   26     0       0       0    -999    -999     0.000
# 26     1953     10   27     0       0       0    -999    -999     0.000
# 27     1953     10   28     0       0       0    -999    -999     0.000
# 28     1953     10   29     0       0       0    -999    -999     0.000
# 29     1953     10   30     0       0       0    -999    -999     0.000
# ...     ...    ...  ...   ...     ...     ...     ...     ...       ...
# 19601  2007      6    1     0       0       0      80      33     0.000
# 19602  2007      6    2     0       0       0      77      36     0.000
# 19603  2007      6    3     0       0       0      75      28     0.000
# 19604  2007      6    4     0       0       0      71      41     0.000
# 19605  2007      6    5     0       0       0      54      32     5.080
# 19606  2007      6    6     0       0       0      46      25     0.762
# 19607  2007      6    7     0       0       0      62      22     0.000
# 19608  2007      6    8     0       0       0      63      26     0.000
# 19609  2007      6    9     0       0       0      73      29     0.000
# 19610  2007      6   10     0       0       0      69      33     0.000
# 19611  2007      6   11     0       0       0      71      33     0.000
# 19612  2007      6   12     0       0       0      77      30     0.000
# 19613  2007      6   13     0       0       0      81      33     0.000
# 19614  2007      6   14     0       0       0      81      37     0.000
# 19615  2007      6   15     0       0       0      80      33     0.000
# 19616  2007      6   16     0       0       0      75      37     0.000
# 19617  2007      6   17     0       0       0      79      30     0.000
# 19618  2007      6   18     0       0       0      81      31     0.000
# 19619  2007      6   19     0       0       0      77      34     0.000
# 19620  2007      6   20     0       0       0      75      38     0.000
# 19621  2007      6   21     0       0       0      79      31     0.000
# 19622  2007      6   22     0       0       0      78      27     0.000
# 19623  2007      6   23     0       0       0      75      30     0.000
# 19624  2007      6   24     0       0       0      69      27     0.000
# 19625  2007      6   25     0       0       0      78      26     0.000
# 19626  2007      6   26     0       0       0      78      32     0.000
# 19627  2007      6   27     0       0       0      77      30     0.000
# 19628  2007      6   28     0       0       0      72      31     0.000
# 19629  2007      6   29     0       0       0      70      45     0.000
# 19630  2007      6   30     0       0       0      75      41     0.000
#
#        runoff_0       Date
# 0          2.90 1953-10-01
# 1          2.90 1953-10-02
# 2          2.90 1953-10-03
# 3          2.90 1953-10-04
# 4          2.90 1953-10-05
# 5          2.90 1953-10-06
# 6          2.90 1953-10-07
# 7          2.80 1953-10-08
# 8          2.90 1953-10-09
# 9          3.00 1953-10-10
# 10         3.20 1953-10-11
# 11         3.00 1953-10-12
# 12         3.00 1953-10-13
# 13         3.00 1953-10-14
# 14         3.00 1953-10-15
# 15         3.00 1953-10-16
# 16         3.00 1953-10-17
# 17         5.50 1953-10-18
# 18         3.80 1953-10-19
# 19         3.30 1953-10-20
# 20         3.30 1953-10-21
# 21         3.30 1953-10-22
# 22         3.30 1953-10-23
# 23         3.20 1953-10-24
# 24         3.20 1953-10-25
# 25         3.20 1953-10-26
# 26         3.20 1953-10-27
# 27         3.20 1953-10-28
# 28         3.20 1953-10-29
# 29         3.20 1953-10-30
# ...         ...        ...
# 19601      4.89 2007-06-01
# 19602      4.68 2007-06-02
# 19603      4.33 2007-06-03
# 19604      4.09 2007-06-04
# 19605      4.20 2007-06-05
# 19606      4.62 2007-06-06
# 19607      4.26 2007-06-07
# 19608      3.97 2007-06-08
# 19609      3.76 2007-06-09
# 19610      3.59 2007-06-10
# 19611      3.44 2007-06-11
# 19612      3.25 2007-06-12
# 19613      3.10 2007-06-13
# 19614      3.00 2007-06-14
# 19615      2.87 2007-06-15
# 19616      2.78 2007-06-16
# 19617      2.74 2007-06-17
# 19618      2.64 2007-06-18
# 19619      2.57 2007-06-19
# 19620      2.48 2007-06-20
# 19621      2.41 2007-06-21
# 19622      2.37 2007-06-22
# 19623      2.34 2007-06-23
# 19624      2.32 2007-06-24
# 19625      2.29 2007-06-25
# 19626      2.25 2007-06-26
# 19627      2.20 2007-06-27
# 19628      2.17 2007-06-28
# 19629      2.14 2007-06-29
# 19630      2.11 2007-06-30
#
# [19631 rows x 11 columns]

# %% [markdown]
# ### (2.d) Access MODFLOW data in pyGSFLOW
# All data related to MODFLOW can be accessed and assigned using .mf object. This object is a Flopy instant; thus all operations we learnt about Flopy can be used here.

# %%
# !jupyter nbconvert --to script pygsflow_intro.ipynb
# Out:
# [NbConvertApp] Converting notebook pygsflow_intro.ipynb to script
# [NbConvertApp] Writing 7014 bytes to pygsflow_intro.py
